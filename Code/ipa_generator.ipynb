# %%
# Import necessary libraries
import string
from mlphon import PhoneticAnalyser

# %%
# Create an object for PhoneticAnalyser()
mlphon = PhoneticAnalyser()

# %%
# Read the list of Malayalam words from the vocabulary file
mlwords = []
with open("ml_vocab.txt", encoding = "utf-8") as file:
    mlwords = file.read().splitlines()

# %%
len(mlwords)
# Out:
# 120870

# %%
def split_ipa(word, ml_ipa):
    """
    Function to split the IPA representation of a Malayalam word into individual phonemes
    :param word: string, Malayalam word
    :param IPA: string, IPA representation of word
    :return: the split IPA as a string
    """
    ipa_split = []   # Initialize an empty list to store the split IPA
    idx = 0   # Initialize an index variable to keep track of the current position in the split IPA list
    for ch in ml_ipa[0]:   # Iterate over the characters of the IPA representation
        # if character is " ̪ "[1] or "ː", concatenate the character to the last element of ipa_split
        if ch == ' ̪ '[1] or ch == "ː":
            ipa_split[idx-1] = ipa_split[idx-1] + ch + (' ')
        # check if character is '̯'
        elif ch == '̯':
                # handle special cases where a single phoneme comrpises of multiple characters. Eg: "au̯" is one phoneme
                if ipa_split[idx-1] in ['u', 'i'] and ipa_split[idx-2] == 'a':
                    ipa_split[idx-2] = ipa_split[idx-2] + ipa_split[idx-1] + ch + (' ')
                    ipa_split = ipa_split[:-1]
                    idx -= 1
                else:
                    ipa_split[idx-1] = ipa_split[idx-1] + ch + (' ')
        # if character is is "ɨ" and the last element of ipa_split is "r", add character to ipa_split
        elif ch =="ɨ" and ipa_split[idx-1] == "r":
            ipa_split[idx-1] = ipa_split[idx-1] + ch + (' ')
        # check if the character is "ʃ" 
        elif ch == "ʃ":
            # if character occurs at the beginning of the IPA representation, add character to ipa_split
            if idx == 0:
                ipa_split.append(ch)
                idx += 1
            # the last element of ipa_split is " ͡ "[1], concatenate the last two elements and the current character to the second last element (before space).
            elif ipa_split[idx-1] == ' ͡ '[1]:
                ipa_split[idx-2] = ipa_split[idx-2] + ' ͡ '[1] + ch + (' ')
                ipa_split = ipa_split[:-1]
                idx -=1
        # check if the character is "ʰ" or "ʱ"
        elif ch == "ʰ" or ch == "ʱ":
            # if the last element of ipa_split is more than one character, it replaces the space with the current character
            if len(ipa_split[idx-1]) > 1:
                ipa_split[idx-1] = ipa_split[idx-1][:-1] + ch + (' ')
            # else add character to ipa_split
            else:
                ipa_split[idx-1] = ipa_split[idx-1] + ch + (' ')
        # if none of the conditions are met, append the current character to ipa_split
        else:
            ipa_split.append(ch)
            idx += 1
    # if continuent phoneme has only one character, append a space character. Eg., "a" -> "a "
    ipa_split = [ch + ' ' if len(ch) == 1 else ch for idx, ch in enumerate(ipa_split)]
    ipa_split = ''.join(ipa_split)   # Join all characters in the list to form a single string
    ipa_split = ipa_split.rstrip()   # Remove trailing whitespaces, if any
    return ipa_split

# %%
def get_ipa(input_words):
    """
    Function that generates IPA representation for a Malayalam word or a list of Malayaalam words.
    :param input_word: a string or a list of strings of Malayalam word(s)
    :return: a dictionary, with <malayalam_word>:<space seperated IPA representation> as the key-value pair
    """
    ipa = {}    # Initialize an empty dictionary to store the word-IPA pairs
    # Assign input to mlwords depending on datatype (string vs list of strings)
    mlwords = [''.join(input_words.split())] if isinstance(input_words, str) else input_words
    for word in mlwords:
        try:
            # If current word has a valid IPA representation in mlphon library, use it as the IPA representation
            ml_ipa = mlphon.grapheme_to_phoneme(word)
        except ValueError:
            # Else, concatenate IPA representation of constituent letters
            ml_ipa[0] = ''.join([mlphon.grapheme_to_phoneme(letter)[0] for letter in word])
        ipa[word] = ' '.join(split_ipa(word, ml_ipa).split()) 
    return ipa

# %%
ml_ipa = get_ipa(mlwords)
ml_ipa
# Out:
# {'അ': 'a',
#  'അം': 'a m',
#  'അആ': 'a aː',
#  'അകം': 'a k a m',
#  'അകണശ്വേതകോശങ്ങൾ': 'a k a ɳ a ʋ eː t̪ a k oː a ŋ ŋ a ɭ',
#  'അകത്തളങ്ങളിൽ': 'a k a t̪ t̪ a ɭ a ŋ ŋ a ɭ i l',
#  'അകത്തളത്തിൽ': 'a k a t̪ t̪ a ɭ a t̪ t̪ i l',
#  'അകത്താക്കി': 'a k a t̪ t̪ aː k k i',
#  'അകത്തി': 'a k a t̪ t̪ i',
#  'അകത്തു': 'a k a t̪ t̪ u',
#  'അകത്തും': 'a k a t̪ t̪ u m',
#  'അകത്തുകയറി': 'a k a t̪ t̪ u k a j a r i',
#  'അകത്തുനിന്നു': 'a k a t̪ t̪ u n i n̪ n̪ u',
#  'അകത്തുനിന്നും': 'a k a t̪ t̪ u n i n̪ n̪ u m',
#  'അകത്തുനിന്ന്': 'a k a t̪ t̪ u n i n̪ n̪ ə',
#  'അകത്തുള്ള': 'a k a t̪ t̪ u ɭ ɭ a',
#  'അകത്തെ': 'a k a t̪ t̪ e',
#  'അകത്തേ': 'a k a t̪ t̪ eː',
#  'അകത്തേക്കു': 'a k a t̪ t̪ eː k k u',
#  'അകത്തേക്കും': 'a k a t̪ t̪ eː k k u m',
#  'അകത്തേക്ക്': 'a k a t̪ t̪ eː k k ə',
#  'അകത്തേത്തറ': 'a k a t̪ t̪ eː t̪ t̪ a r a',
#  'അകത്തേയ്ക്കു': 'a k a t̪ t̪ eː j k k u',
#  'അകത്തേയ്ക്ക്': 'a k a t̪ t̪ eː j k k ə',
#  'അകത്തോ': 'a k a t̪ t̪ oː',
#  'അകത്ത്': 'a k a t̪ t̪ ə',
#  'അകനാനൂറ്': 'a k a n aː n uː r ə',
#  'അകന്ന': 'a k a n̪ n̪ a',
#  'അകന്നകന്നു': 'a k a n̪ n̪ a k a n̪ n̪ u',
#  'അകന്നു': 'a k a n̪ n̪ u',
#  'അകന്ന്': 'a k a n̪ n̪ ə',
#  'അകപ്പെടുകയും': 'a k a p p e ʈ u k a j u m',
#  'അകപ്പെടുന്ന': 'a k a p p e ʈ u n̪ n̪ a',
#  'അകപ്പെട്ട': 'a k a p p e ʈ ʈ a',
#  'അകപ്പെട്ടത്': 'a k a p p e ʈ ʈ a t̪ ə',
#  'അകപ്പെട്ടവരെ': 'a k a p p e ʈ ʈ a ʋ a ɾ e',
#  'അകപ്പെട്ടിരുന്നേനെ': 'a k a p p e ʈ ʈ i ɾ u n̪ n̪ eː n e',
#  'അകപ്പെട്ടു': 'a k a p p e ʈ ʈ u',
#  'അകപ്പെട്ടുപോയ': 'a k a p p e ʈ ʈ u p oː j a',
#  'അകപ്പെട്ട്': 'a k a p p e ʈ ʈ ə',
#  'അകമഴിഞ്ഞ': 'a k a m a ɻ i ɲ ɲ a',
#  'അകമഴിഞ്ഞ്': 'a k a m a ɻ i ɲ ɲ ə',
#  'അകമേ': 'a k a m eː',
#  'അകമ്പടി': 'a k a m p a ʈ i',
#  'അകമ്പടിയായി': 'a k a m p a ʈ i j aː j i',
#  'അകമ്പടിയിൽ': 'a k a m p a ʈ i j i l',
#  'അകമ്പടിയോടെ': 'a k a m p a ʈ i j oː ʈ e',
#  'അകമ്പടിയോടെയാണ്': 'a k a m p a ʈ i j oː ʈ e j aː ɳ ə',
#  'അകമ്പാടം': 'a k a m p aː ʈ a m',
#  'അകലം': 'a k a l a m',
#  'അകലങ്ങളിൽ': 'a k a l a ŋ ŋ a ɭ i l',
#  'അകലണമെങ്കിൽ': 'a k a l a ɳ a m e ŋ k i l',
#  'അകലത്തിന്റെ': 'a k a l a t̪ t̪ i n ṯ e',
#  'അകലത്തിലായിരിക്കണം': 'a k a l a t̪ t̪ i l aː j i ɾ i k k a ɳ a m',
#  'അകലത്തിൽ': 'a k a l a t̪ t̪ i l',
#  'അകലമാണ്': 'a k a l a m aː ɳ ə',
#  'അകലവും': 'a k a l a ʋ u m',
#  'അകലാട്': 'a k a l aː ʈ ə',
#  'അകലാൻ': 'a k a l aː n',
#  'അകലുകയും': 'a k a l u k a j u m',
#  'അകലുന്നു': 'a k a l u n̪ n̪ u',
#  'അകലെ': 'a k a l e',
#  'അകലെയല്ല': 'a k a l e j a l l a',
#  'അകലെയല്ലാതെ': 'a k a l e j a l l aː t̪ e',
#  'അകലെയാണ്': 'a k a l e j aː ɳ ə',
#  'അകലെയായി': 'a k a l e j aː j i',
#  'അകലെയായിരുന്നു': 'a k a l e j aː j i ɾ u n̪ n̪ u',
#  'അകലെയുളള': 'a k a l e j u ɭ a ɭ a',
#  'അകലെയുള്ള': 'a k a l e j u ɭ ɭ a',
#  'അകലേക്ക്': 'a k a l eː k k ə',
#  'അകൽച്ച': 'a k a l t͡ʃ t͡ʃ a',
#  'അകൽച്ചയും': 'a k a l t͡ʃ t͡ʃ a j u m',
#  'അകവും': 'a k a ʋ u m',
#  'അകവൂർ': 'a k a ʋ uː r',
#  'അകറ്റാനും': 'a k a ṯ ṯ aː n u m',
#  'അകറ്റാനുള്ള': 'a k a ṯ ṯ aː n u ɭ ɭ a',
#  'അകറ്റാൻ': 'a k a ṯ ṯ aː n',
#  'അകറ്റി': 'a k a ṯ ṯ i',
#  'അകറ്റിയത്': 'a k a ṯ ṯ i j a t̪ ə',
#  'അകറ്റിയില്ലെങ്കിൽ': 'a k a ṯ ṯ i j i l l e ŋ k i l',
#  'അകറ്റും': 'a k a ṯ ṯ u m',
#  'അകറ്റുകയും': 'a k a ṯ ṯ u k a j u m',
#  'അകറ്റുന്ന': 'a k a ṯ ṯ u n̪ n̪ a',
#  'അകറ്റുന്നു': 'a k a ṯ ṯ u n̪ n̪ u',
#  'അകാദമിയുടെ': 'a k aː d̪ a m i j u ʈ e',
#  'അകാൻ': 'a k aː n',
#  'അകാരണമായ': 'a k aː ɾ a ɳ a m aː j a',
#  'അകാരണമായി': 'a k aː ɾ a ɳ a m aː j i',
#  'അകാർബണിക': 'a k aː r b a ɳ i k a',
#  'അകാല': 'a k aː l a',
#  'അകാലത്തിൽ': 'a k aː l a t̪ t̪ i l',
#  'അകാലി': 'a k aː l i',
#  'അകാലിദൾ': 'a k aː l i d̪ a ɭ',
#  'അകിര': 'a k i ɾ a',
#  'അകിരയുടെ': 'a k i ɾ a j u ʈ e',
#  'അകിരയ്ക്ക്': 'a k i ɾ a j k k ə',
#  'അകിൽ': 'a k i l',
#  'അകെ': 'a k e',
#  'അകെയുള്ള': 'a k e j u ɭ ɭ a',
#  'അകൈതവമായ': 'a k ai̯ t̪ a ʋ a m aː j a',
#  'അക്': 'a k ə',
#  'അക്ക': 'a k k a',
#  'അക്കം': 'a k k a m',
#  'അക്കങ്ങളാണ്': 'a k k a ŋ ŋ a ɭ aː ɳ ə',
#  'അക്കങ്ങളും': 'a k k a ŋ ŋ a ɭ u m',
#  'അക്കങ്ങളുടെ': 'a k k a ŋ ŋ a ɭ u ʈ e',
#  'അക്കങ്ങൾ': 'a k k a ŋ ŋ a ɭ',
#  'അക്കത്തിൽ': 'a k k a t̪ t̪ i l',
#  'അക്കമിട്ടു': 'a k k a m i ʈ ʈ u',
#  'അക്കമിട്ട്': 'a k k a m i ʈ ʈ ə',
#  'അക്കര': 'a k k a ɾ a',
#  'അക്കരയ്ക്കു': 'a k k a ɾ a j k k u',
#  'അക്കരവീട്ടിലെ': 'a k k a ɾ a ʋ iː ʈ ʈ i l e',
#  'അക്കരെ': 'a k k a ɾ e',
#  'അക്കാഡമി': 'a k k aː ɖ a m i',
#  'അക്കാഡമിക്': 'a k k aː ɖ a m i k ə',
#  'അക്കാഡമിയിൽ': 'a k k aː ɖ a m i j i l',
#  'അക്കാഡമിയുടെ': 'a k k aː ɖ a m i j u ʈ e',
#  'അക്കാദമി': 'a k k aː d̪ a m i',
#  'അക്കാദമിക': 'a k k aː d̪ a m i k a',
#  'അക്കാദമികൾ': 'a k k aː d̪ a m i k a ɭ',
#  'അക്കാദമിക്': 'a k k aː d̪ a m i k ə',
#  'അക്കാദമിക്ക്': 'a k k aː d̪ a m i k k ə',
#  'അക്കാദമിയ': 'a k k aː d̪ a m i j a',
#  'അക്കാദമിയാണ്': 'a k k aː d̪ a m i j aː ɳ ə',
#  'അക്കാദമിയിലും': 'a k k aː d̪ a m i j i l u m',
#  'അക്കാദമിയിലെ': 'a k k aː d̪ a m i j i l e',
#  'അക്കാദമിയിൽ': 'a k k aː d̪ a m i j i l',
#  'അക്കാദമിയിൽചേർന്നത്': 'a k k aː d̪ a m i j i l t͡ʃ eː r n̪ n̪ a t̪ ə',
#  'അക്കാദമിയും': 'a k k aː d̪ a m i j u m',
#  'അക്കാദമിയുടെ': 'a k k aː d̪ a m i j u ʈ e',
#  'അക്കാദമിയുടെയും': 'a k k aː d̪ a m i j u ʈ e j u m',
#  'അക്കാദമിയെ': 'a k k aː d̪ a m i j e',
#  'അക്കാദ്': 'a k k aː d̪ ə',
#  'അക്കാന്തേസീ': 'a k k aː n̪ t̪ eː s iː',
#  'അക്കാരണം': 'a k k aː ɾ a ɳ a m',
#  'അക്കാരണത്താൽ': 'a k k aː ɾ a ɳ a t̪ t̪ aː l',
#  'അക്കാര്യം': 'a k k aː ɾ j a m',
#  'അക്കാര്യത്തിൽ': 'a k k aː ɾ j a t̪ t̪ i l',
#  'അക്കാലം': 'a k k aː l a m',
#  'അക്കാലങ്ങളിലാണ്': 'a k k aː l a ŋ ŋ a ɭ i l aː ɳ ə',
#  'അക്കാലങ്ങളിൽ': 'a k k aː l a ŋ ŋ a ɭ i l',
#  'അക്കാലത്താണ്': 'a k k aː l a t̪ t̪ aː ɳ ə',
#  'അക്കാലത്തു': 'a k k aː l a t̪ t̪ u',
#  'അക്കാലത്തു്': 'a k k aː l a t̪ t̪ ə',
#  'അക്കാലത്തെ': 'a k k aː l a t̪ t̪ e',
#  'അക്കാലത്ത്': 'a k k aː l a t̪ t̪ ə',
#  'അക്കിത്തം': 'a k k i t̪ t̪ a m',
#  'അക്കിനേനി': 'a k k i n eː n i',
#  'അക്കിലിസ്': 'a k k i l i s ə',
#  'അക്കീരമൺ': 'a k k iː ɾ a m a ɳ',
#  'അക്കു': 'a k k u',
#  'അക്കുപ്പട്ടി': 'a k k u p p a ʈ ʈ i',
#  'അക്കുപ്പട്ടിയും': 'a k k u p p a ʈ ʈ i j u m',
#  'അക്കുപ്പട്ടിയെ': 'a k k u p p a ʈ ʈ i j e',
#  'അക്കൂട്ടത്തിൽ': 'a k k uː ʈ ʈ a t̪ t̪ i l',
#  'അക്കെ': 'a k k e',
#  'അക്കേദിയൻ': 'a k k eː d̪ i j a n',
#  'അക്കേഷ്യ': 'a k k eː ʂ j a',
#  'അക്കൊല്ലം': 'a k k o l l a m',
#  'അക്കൊല്ലത്തെ': 'a k k o l l a t̪ t̪ e',
#  'അക്കോൺ': 'a k k oː ɳ',
#  'അക്കൗണ്ടൻസി': 'a k k au̯ ɳ ʈ a n s i',
#  'അക്കൗണ്ടന്റായിരുന്നു': 'a k k au̯ ɳ ʈ a n ṯ aː j i ɾ u n̪ n̪ u',
#  'അക്കൗണ്ടന്റ്': 'a k k au̯ ɳ ʈ a n ṯ ə',
#  'അക്കൗണ്ടിംഗ്': 'a k k au̯ ɳ ʈ i m ɡ ə',
#  'അക്കൗണ്ടിങ്': 'a k k au̯ ɳ ʈ i ŋ ə',
#  'അക്കൗണ്ടിങ്ങ്': 'a k k au̯ ɳ ʈ i ŋ ŋ ə',
#  'അക്കൗണ്ടിന്': 'a k k au̯ ɳ ʈ i n ə',
#  'അക്കൗണ്ടിന്റെ': 'a k k au̯ ɳ ʈ i n ṯ e',
#  'അക്കൗണ്ടിലാണ്': 'a k k au̯ ɳ ʈ i l aː ɳ ə',
#  'അക്കൗണ്ടിലുള്ള': 'a k k au̯ ɳ ʈ i l u ɭ ɭ a',
#  'അക്കൗണ്ടിലൂടെ': 'a k k au̯ ɳ ʈ i l uː ʈ e',
#  'അക്കൗണ്ടിലൂടെയാണ്': 'a k k au̯ ɳ ʈ i l uː ʈ e j aː ɳ ə',
#  'അക്കൗണ്ടിലെ': 'a k k au̯ ɳ ʈ i l e',
#  'അക്കൗണ്ടിലേക്കു': 'a k k au̯ ɳ ʈ i l eː k k u',
#  'അക്കൗണ്ടിലേക്ക്': 'a k k au̯ ɳ ʈ i l eː k k ə',
#  'അക്കൗണ്ടിലേയ്ക്ക്': 'a k k au̯ ɳ ʈ i l eː j k k ə',
#  'അക്കൗണ്ടിൽ': 'a k k au̯ ɳ ʈ i l',
#  'അക്കൗണ്ടും': 'a k k au̯ ɳ ʈ u m',
#  'അക്കൗണ്ടുകളാണ്': 'a k k au̯ ɳ ʈ u k a ɭ aː ɳ ə',
#  'അക്കൗണ്ടുകളിലൂടെ': 'a k k au̯ ɳ ʈ u k a ɭ i l uː ʈ e',
#  'അക്കൗണ്ടുകളിലെ': 'a k k au̯ ɳ ʈ u k a ɭ i l e',
#  'അക്കൗണ്ടുകളിലേക്ക്': 'a k k au̯ ɳ ʈ u k a ɭ i l eː k k ə',
#  'അക്കൗണ്ടുകളിൽ': 'a k k au̯ ɳ ʈ u k a ɭ i l',
#  'അക്കൗണ്ടുകളും': 'a k k au̯ ɳ ʈ u k a ɭ u m',
#  'അക്കൗണ്ടുകളുടെ': 'a k k au̯ ɳ ʈ u k a ɭ u ʈ e',
#  'അക്കൗണ്ടുകൾ': 'a k k au̯ ɳ ʈ u k a ɭ',
#  'അക്കൗണ്ടുകൾക്ക്': 'a k k au̯ ɳ ʈ u k a ɭ k k ə',
#  'അക്കൗണ്ടുമായി': 'a k k au̯ ɳ ʈ u m aː j i',
#  'അക്കൗണ്ടുള്ള': 'a k k au̯ ɳ ʈ u ɭ ɭ a',
#  'അക്കൗണ്ട്': 'a k k au̯ ɳ ʈ ə',
#  'അക്കൗണ്ട്സ്': 'a k k au̯ ɳ ʈ s ə',
#  'അക്തർ': 'a k t̪ a r',
#  'അക്തറിനെതിരെ': 'a k t̪ a r i n e t̪ i ɾ e',
#  'അക്ബരിയ്യ': 'a k b a ɾ i j j a',
#  'അക്ബർ': 'a k b a r',
#  'അൿബർ': 'a k b a r',
#  'അക്ബർക്കുണ്ടായി': 'a k b a r k k u ɳ ʈ aː j i',
#  'അക്ബറിനു': 'a k b a r i n u',
#  'അക്ബറിനെ': 'a k b a r i n e',
#  'അക്ബറിനെതിരെ': 'a k b a r i n e t̪ i ɾ e',
#  'അക്ബറിന്': 'a k b a r i n ə',
#  'അക്ബറിന്റെ': 'a k b a r i n ṯ e',
#  'അക്ബറും': 'a k b a r u m',
#  'അക്ബറുടെ': 'a k b a r u ʈ e',
#  'അക്ബറുദ്ദീൻ': 'a k b a r u d̪ d̪ iː n',
#  'അക്മൽ': 'a k m a l',
#  'അക്യൂട്ട്': 'a k j uː ʈ ʈ ə',
#  'അക്രം': 'a k r a m',
#  'അക്രഡിറ്റേഷൻ': 'a k r a ɖ i ṯ ṯ eː ʂ a n',
#  'അക്രമ': 'a k r a m a',
#  'അക്രമം': 'a k r a m a m',
#  'അക്രമകാരികളായ': 'a k r a m a k aː ɾ i k a ɭ aː j a',
#  'അക്രമങ്ങളാണ്': 'a k r a m a ŋ ŋ a ɭ aː ɳ ə',
#  'അക്രമങ്ങളിൽ': 'a k r a m a ŋ ŋ a ɭ i l',
#  'അക്രമങ്ങളും': 'a k r a m a ŋ ŋ a ɭ u m',
#  'അക്രമങ്ങളുടെ': 'a k r a m a ŋ ŋ a ɭ u ʈ e',
#  'അക്രമങ്ങളെ': 'a k r a m a ŋ ŋ a ɭ e',
#  'അക്രമങ്ങൾ': 'a k r a m a ŋ ŋ a ɭ',
#  'അക്രമങ്ങൾക്കും': 'a k r a m a ŋ ŋ a ɭ k k u m',
#  'അക്രമങ്ങൾക്കെതിരെ': 'a k r a m a ŋ ŋ a ɭ k k e t̪ i ɾ e',
#  'അക്രമങ്ങൾക്ക്': 'a k r a m a ŋ ŋ a ɭ k k ə',
#  'അക്രമണ': 'a k r a m a ɳ a',
#  'അക്രമണം': 'a k r a m a ɳ a m',
#  'അക്രമണങ്ങൾ': 'a k r a m a ɳ a ŋ ŋ a ɭ',
#  'അക്രമണത്തിന്': 'a k r a m a ɳ a t̪ t̪ i n ə',
#  'അക്രമണത്തിൽ': 'a k r a m a ɳ a t̪ t̪ i l',
#  'അക്രമത്തിനിരയായ': 'a k r a m a t̪ t̪ i n i ɾ a j aː j a',
#  'അക്രമത്തിനു': 'a k r a m a t̪ t̪ i n u',
#  'അക്രമത്തിനും': 'a k r a m a t̪ t̪ i n u m',
#  'അക്രമത്തിനെതിരെ': 'a k r a m a t̪ t̪ i n e t̪ i ɾ e',
#  'അക്രമത്തിന്': 'a k r a m a t̪ t̪ i n ə',
#  'അക്രമത്തിന്റെ': 'a k r a m a t̪ t̪ i n ṯ e',
#  'അക്രമത്തിന്റെയും': 'a k r a m a t̪ t̪ i n ṯ e j u m',
#  'അക്രമത്തിലും': 'a k r a m a t̪ t̪ i l u m',
#  'അക്രമത്തിലൂടെ': 'a k r a m a t̪ t̪ i l uː ʈ e',
#  'അക്രമത്തിലേക്ക്': 'a k r a m a t̪ t̪ i l eː k k ə',
#  'അക്രമത്തിൽ': 'a k r a m a t̪ t̪ i l',
#  'അക്രമത്തെ': 'a k r a m a t̪ t̪ e',
#  'അക്രമനടപടികളോട്': 'a k r a m a n a ʈ a p a ʈ i k a ɭ oː ʈ ə',
#  'അക്രമഭീഷണിയുടെ': 'a k r a m a bʱ iː ʂ a ɳ i j u ʈ e',
#  'അക്രമമാണ്': 'a k r a m a m aː ɳ ə',
#  'അക്രമമുണ്ടായത്': 'a k r a m a m u ɳ ʈ aː j a t̪ ə',
#  'അക്രമരഹിത': 'a k r a m a ɾ a ɦ i t̪ a',
#  'അക്രമരാഷ്ട്രീയം': 'a k r a m a ɾ aː ʂ ʈ r iː j a m',
#  'അക്രമവും': 'a k r a m a ʋ u m',
#  'അക്രമവുമായി': 'a k r a m a ʋ u m aː j i',
#  'അക്രമസംഭവങ്ങളിൽ': 'a k r a m a s a m bʱ a ʋ a ŋ ŋ a ɭ i l',
#  'അക്രമസംഭവങ്ങൾ': 'a k r a m a s a m bʱ a ʋ a ŋ ŋ a ɭ',
#  'അക്രമാസക്ത': 'a k r a m aː s a k t̪ a',
#  'അക്രമാസക്തമായ': 'a k r a m aː s a k t̪ a m aː j a',
#  'അക്രമാസക്തമായി': 'a k r a m aː s a k t̪ a m aː j i',
#  'അക്രമാസക്തരായ': 'a k r a m aː s a k t̪ a ɾ aː j a',
#  'അക്രമാസക്തരായി': 'a k r a m aː s a k t̪ a ɾ aː j i',
#  'അക്രമി': 'a k r a m i',
#  'അക്രമികളായ': 'a k r a m i k a ɭ aː j a',
#  'അക്രമികളിൽ': 'a k r a m i k a ɭ i l',
#  'അക്രമികളും': 'a k r a m i k a ɭ u m',
#  'അക്രമികളുടെ': 'a k r a m i k a ɭ u ʈ e',
#  'അക്രമികളെ': 'a k r a m i k a ɭ e',
#  'അക്രമികൾ': 'a k r a m i k a ɭ',
#  'അക്രമികൾക്കെതിരെ': 'a k r a m i k a ɭ k k e t̪ i ɾ e',
#  'അക്രമികൾക്ക്': 'a k r a m i k a ɭ k k ə',
#  'അക്രമിക്കപ്പെട്ട': 'a k r a m i k k a p p e ʈ ʈ a',
#  'അക്രമിക്കാൻ': 'a k r a m i k k aː n',
#  'അക്രമിക്കുകയായിരുന്നു': 'a k r a m i k k u k a j aː j i ɾ u n̪ n̪ u',
#  'അക്രമിക്കുകയും': 'a k r a m i k k u k a j u m',
#  'അക്രമിച്ച': 'a k r a m i t͡ʃ t͡ʃ a',
#  'അക്രമിച്ചത്': 'a k r a m i t͡ʃ t͡ʃ a t̪ ə',
#  'അക്രമിച്ചു': 'a k r a m i t͡ʃ t͡ʃ u',
#  'അക്രമിച്ച്': 'a k r a m i t͡ʃ t͡ʃ ə',
#  'അക്രമിയുടെ': 'a k r a m i j u ʈ e',
#  'അക്രമിയെ': 'a k r a m i j e',
#  'അക്രമിസംഘം': 'a k r a m i s a m ɡʱ a m',
#  'അക്രിലിക്': 'a k r i l i k ə',
#  'അക്രെഡിറ്റേഷൻ': 'a k r e ɖ i ṯ ṯ eː ʂ a n',
#  'അക്രേഷൻ': 'a k r eː ʂ a n',
#  'അക്രോബാറ്റ്': 'a k r oː b aː ṯ ṯ ə',
#  'അക്വയർ': 'a k ʋ a j a r',
#  'അക്വാ': 'a k ʋ aː',
#  'അക്വിസിഷൻ': 'a k ʋ i s i ʂ a n',
#  'അക്വീനാസിനെ': 'a k ʋ iː n aː s i n e',
#  'അക്വീനാസിന്റെ': 'a k ʋ iː n aː s i n ṯ e',
#  'അക്വീനാസ്': 'a k ʋ iː n aː s ə',
#  'അക്വേറിയം': 'a k ʋ eː r i j a m',
#  'അക്വേറിയങ്ങളിൽ': 'a k ʋ eː r i j a ŋ ŋ a ɭ i l',
#  'അക്വേറിയത്തിൽ': 'a k ʋ eː r i j a t̪ t̪ i l',
#  'അക്ഷം': 'a k ʂ a m',
#  'അക്ഷത്തിൽ': 'a k ʂ a t̪ t̪ i l',
#  'അക്ഷന്തവ്യമായ': 'a k ʂ a n̪ t̪ a ʋ j a m aː j a',
#  'അക്ഷമ': 'a k ʂ a m a',
#  'അക്ഷമനായി': 'a k ʂ a m a n aː j i',
#  'അക്ഷമയോടെ': 'a k ʂ a m a j oː ʈ e',
#  'അക്ഷമരായി': 'a k ʂ a m a ɾ aː j i',
#  'അക്ഷയ': 'a k ʂ a j a',
#  'അക്ഷയതൃതീയ': 'a k ʂ a j a t̪ rɨ t̪ iː j a',
#  'അക്ഷയശ്രീ': 'a k ʂ a j a r iː',
#  'അക്ഷയ്': 'a k ʂ a j ə',
#  'അക്ഷര': 'a k ʂ a ɾ a',
#  'അക്ഷരം': 'a k ʂ a ɾ a m',
#  'അക്ഷരങ്ങളാണ്': 'a k ʂ a ɾ a ŋ ŋ a ɭ aː ɳ ə',
#  'അക്ഷരങ്ങളിലൂടെ': 'a k ʂ a ɾ a ŋ ŋ a ɭ i l uː ʈ e',
#  'അക്ഷരങ്ങളിൽ': 'a k ʂ a ɾ a ŋ ŋ a ɭ i l',
#  'അക്ഷരങ്ങളും': 'a k ʂ a ɾ a ŋ ŋ a ɭ u m',
#  'അക്ഷരങ്ങളുടെ': 'a k ʂ a ɾ a ŋ ŋ a ɭ u ʈ e',
#  'അക്ഷരങ്ങളെ': 'a k ʂ a ɾ a ŋ ŋ a ɭ e',
#  'അക്ഷരങ്ങൾ': 'a k ʂ a ɾ a ŋ ŋ a ɭ',
#  'അക്ഷരങ്ങൾക്കപ്പുറത്തേയ്ക്ക്': 'a k ʂ a ɾ a ŋ ŋ a ɭ k k a p p u r a t̪ t̪ eː j k k ə',
#  'അക്ഷരങ്ങൾക്ക്': 'a k ʂ a ɾ a ŋ ŋ a ɭ k k ə',
#  'അക്ഷരത്തിന്': 'a k ʂ a ɾ a t̪ t̪ i n ə',
#  'അക്ഷരത്തിന്റെ': 'a k ʂ a ɾ a t̪ t̪ i n ṯ e',
#  'അക്ഷരത്തിലാരംഭിക്കുന്ന': 'a k ʂ a ɾ a t̪ t̪ i l aː ɾ a m bʱ i k k u n̪ n̪ a',
#  'അക്ഷരത്തിലും': 'a k ʂ a ɾ a t̪ t̪ i l u m',
#  'അക്ഷരത്തിൽ': 'a k ʂ a ɾ a t̪ t̪ i l',
#  'അക്ഷരത്തെറ്റുകൾ': 'a k ʂ a ɾ a t̪ t̪ e ṯ ṯ u k a ɭ',
#  'അക്ഷരത്തെറ്റ്': 'a k ʂ a ɾ a t̪ t̪ e ṯ ṯ ə',
#  'അക്ഷരംപ്രതി': 'a k ʂ a ɾ a m p r a t̪ i',
#  'അക്ഷരമാണ്': 'a k ʂ a ɾ a m aː ɳ ə',
#  'അക്ഷരമായി': 'a k ʂ a ɾ a m aː j i',
#  'അക്ഷരമാല': 'a k ʂ a ɾ a m aː l a',
#  'അക്ഷരമാലയിലെ': 'a k ʂ a ɾ a m aː l a j i l e',
#  'അക്ഷരമാലയിൽ': 'a k ʂ a ɾ a m aː l a j i l',
#  'അക്ഷരമാലാ': 'a k ʂ a ɾ a m aː l aː',
#  'അക്ഷരമാലാക്രമത്തിൽ': 'a k ʂ a ɾ a m aː l aː k r a m a t̪ t̪ i l',
#  'അക്ഷരവും': 'a k ʂ a ɾ a ʋ u m',
#  'അക്ഷരശ്ലോക': 'a k ʂ a ɾ a l oː k a',
#  'അക്ഷരശ്ലോകം': 'a k ʂ a ɾ a l oː k a m',
#  'അക്ഷരസ്ഫുടതയോടെ': 'a k ʂ a ɾ a s pʰ u ʈ a t̪ a j oː ʈ e',
#  'അക്ഷരാഭ്യാസം': 'a k ʂ a ɾ aː bʱ j aː s a m',
#  'അക്ഷരാർത്ഥത്തിൽ': 'a k ʂ a ɾ aː r t̪ t̪ʰ a t̪ t̪ i l',
#  'അക്ഷരാർഥത്തിൽ': 'a k ʂ a ɾ aː r t̪ʰ a t̪ t̪ i l',
#  'അക്ഷരേക്ഷാംശങ്ങൾ': 'a k ʂ a ɾ eː k ʂ aː m a ŋ ŋ a ɭ',
#  'അക്ഷരേഖാംശങ്ങൾ': 'a k ʂ a ɾ eː kʰ aː m a ŋ ŋ a ɭ',
#  'അക്ഷർ': 'a k ʂ a r',
#  'അക്ഷർധാം': 'a k ʂ a r d̪ʱ aː m',
#  'അക്ഷാംശ': 'a k ʂ aː m a',
#  'അക്ഷാംശം': 'a k ʂ aː m a m',
#  'അക്ഷാംശങ്ങളിലുമായിരിക്കും': 'a k ʂ aː m a ŋ ŋ a ɭ i l u m aː j i ɾ i k k u m',
#  'അക്ഷീണ': 'a k ʂ iː ɳ a',
#  'അക്ഷീണം': 'a k ʂ iː ɳ a m',
#  'അക്സർ': 'a k s a r',
#  'അക്സായ്': 'a k s aː j ə',
#  'അഖണ്ഡ': 'a kʰ a ɳ ɖ a',
#  'അഖണ്ഡത': 'a kʰ a ɳ ɖ a t̪ a',
#  'അഖണ്ഡതയും': 'a kʰ a ɳ ɖ a t̪ a j u m',
#  'അഖബ': 'a kʰ a b a',
#  'അഖില': 'a kʰ i l a',
#  'അഖിലകേരള': 'a kʰ i l a k eː ɾ a ɭ a',
#  'അഖിലഭാരത': 'a kʰ i l a bʱ aː ɾ a t̪ a',
#  'അഖിലഭാരതീയ': 'a kʰ i l a bʱ aː ɾ a t̪ iː j a',
#  'അഖിലയുടെ': 'a kʰ i l a j u ʈ e',
#  'അഖിലയെ': 'a kʰ i l a j e',
#  'അഖിലിനെ': 'a kʰ i l i n e',
#  'അഖിലിന്റെ': 'a kʰ i l i n ṯ e',
#  'അഖിലേന്ത്യ': 'a kʰ i l eː n̪ t̪ j a',
#  'അഖിലേന്ത്യാ': 'a kʰ i l eː n̪ t̪ j aː',
#  'അഖിലേന്ത്യാതലത്തിൽ': 'a kʰ i l eː n̪ t̪ j aː t̪ a l a t̪ t̪ i l',
#  'അഖിലേഷിനെ': 'a kʰ i l eː ʂ i n e',
#  'അഖിലേഷിന്റെ': 'a kʰ i l eː ʂ i n ṯ e',
#  'അഖിലേഷും': 'a kʰ i l eː ʂ u m',
#  'അഖിലേഷ്': 'a kʰ i l eː ʂ ə',
#  'അഖിൽ': 'a kʰ i l',
#  'അഖീവയുടെ': 'a kʰ iː ʋ a j u ʈ e',
#  'അഖ്തർ': 'a kʰ t̪ a r',
#  'അഖ്മത്തോവ': 'a kʰ m a t̪ t̪ oː ʋ a',
#  'അഖ്ലാഖിന്റെ': 'a kʰ l aː kʰ i n ṯ e',
#  'അഖ്ലാഖ്': 'a kʰ l aː kʰ ə',
#  'അഖ്സ': 'a kʰ s a',
#  'അംഗ': 'a m ɡ a',
#  'അംഗം': 'a m ɡ a m',
#  'അംഗങ്ങളടക്കമുള്ള': 'a m ɡ a ŋ ŋ a ɭ a ʈ a k k a m u ɭ ɭ a',
#  'അംഗങ്ങളാണ്': 'a m ɡ a ŋ ŋ a ɭ aː ɳ ə',
#  'അംഗങ്ങളായ': 'a m ɡ a ŋ ŋ a ɭ aː j a',
#  'അംഗങ്ങളായവരും': 'a m ɡ a ŋ ŋ a ɭ aː j a ʋ a ɾ u m',
#  'അംഗങ്ങളായവരുടെ': 'a m ɡ a ŋ ŋ a ɭ aː j a ʋ a ɾ u ʈ e',
#  'അംഗങ്ങളായി': 'a m ɡ a ŋ ŋ a ɭ aː j i',
#  'അംഗങ്ങളായിരിക്കും': 'a m ɡ a ŋ ŋ a ɭ aː j i ɾ i k k u m',
#  'അംഗങ്ങളായിരുന്ന': 'a m ɡ a ŋ ŋ a ɭ aː j i ɾ u n̪ n̪ a',
#  'അംഗങ്ങളായിരുന്നു': 'a m ɡ a ŋ ŋ a ɭ aː j i ɾ u n̪ n̪ u',
#  'അംഗങ്ങളായുള്ള': 'a m ɡ a ŋ ŋ a ɭ aː j u ɭ ɭ a',
#  'അംഗങ്ങളിൽ': 'a m ɡ a ŋ ŋ a ɭ i l',
#  'അംഗങ്ങളും': 'a m ɡ a ŋ ŋ a ɭ u m',
#  'അംഗങ്ങളുടെ': 'a m ɡ a ŋ ŋ a ɭ u ʈ e',
#  'അംഗങ്ങളുടെയും': 'a m ɡ a ŋ ŋ a ɭ u ʈ e j u m',
#  'അംഗങ്ങളുടേയും': 'a m ɡ a ŋ ŋ a ɭ u ʈ eː j u m',
#  'അംഗങ്ങളുണ്ടായിരിക്കണം': 'a m ɡ a ŋ ŋ a ɭ u ɳ ʈ aː j i ɾ i k k a ɳ a m',
#  'അംഗങ്ങളുമാണ്': 'a m ɡ a ŋ ŋ a ɭ u m aː ɳ ə',
#  'അംഗങ്ങളുമായ': 'a m ɡ a ŋ ŋ a ɭ u m aː j a',
#  'അംഗങ്ങളുമായി': 'a m ɡ a ŋ ŋ a ɭ u m aː j i',
#  'അംഗങ്ങളുൾപ്പെടെ': 'a m ɡ a ŋ ŋ a ɭ u ɭ p p e ʈ e',
#  'അംഗങ്ങളുള്ള': 'a m ɡ a ŋ ŋ a ɭ u ɭ ɭ a',
#  'അംഗങ്ങളെ': 'a m ɡ a ŋ ŋ a ɭ e',
#  'അംഗങ്ങളെയും': 'a m ɡ a ŋ ŋ a ɭ e j u m',
#  'അംഗങ്ങളേയും': 'a m ɡ a ŋ ŋ a ɭ eː j u m',
#  'അംഗങ്ങളോട്': 'a m ɡ a ŋ ŋ a ɭ oː ʈ ə',
#  'അംഗങ്ങൾ': 'a m ɡ a ŋ ŋ a ɭ',
#  'അംഗങ്ങൾക്കായി': 'a m ɡ a ŋ ŋ a ɭ k k aː j i',
#  'അംഗങ്ങൾക്കിടയിൽ': 'a m ɡ a ŋ ŋ a ɭ k k i ʈ a j i l',
#  'അംഗങ്ങൾക്കു': 'a m ɡ a ŋ ŋ a ɭ k k u',
#  'അംഗങ്ങൾക്കും': 'a m ɡ a ŋ ŋ a ɭ k k u m',
#  'അംഗങ്ങൾക്കുള്ള': 'a m ɡ a ŋ ŋ a ɭ k k u ɭ ɭ a',
#  'അംഗങ്ങൾക്കെതിരെ': 'a m ɡ a ŋ ŋ a ɭ k k e t̪ i ɾ e',
#  'അംഗങ്ങൾക്ക്': 'a m ɡ a ŋ ŋ a ɭ k k ə',
#  'അഗത': 'a ɡ a t̪ a',
#  'അഗതി': 'a ɡ a t̪ i',
#  'അഗതികളുടെ': 'a ɡ a t̪ i k a ɭ u ʈ e',
#  'അഗത്തി': 'a ɡ a t̪ t̪ i',
#  'അംഗത്തിനും': 'a m ɡ a t̪ t̪ i n u m',
#  'അംഗത്തിന്': 'a m ɡ a t̪ t̪ i n ə',
#  'അംഗത്തിന്റെ': 'a m ɡ a t̪ t̪ i n ṯ e',
#  'അംഗത്തെ': 'a m ɡ a t̪ t̪ e',
#  'അംഗത്വ': 'a m ɡ a t̪ ʋ a',
#  'അംഗത്വം': 'a m ɡ a t̪ ʋ a m',
#  'അംഗത്വത്തിനു': 'a m ɡ a t̪ ʋ a t̪ t̪ i n u',
#  'അംഗത്വത്തിന്': 'a m ɡ a t̪ ʋ a t̪ t̪ i n ə',
#  'അംഗത്വത്തിൽ': 'a m ɡ a t̪ ʋ a t̪ t̪ i l',
#  'അംഗത്വമില്ലാത്ത': 'a m ɡ a t̪ ʋ a m i l l aː t̪ t̪ a',
#  'അംഗത്വമുള്ള': 'a m ɡ a t̪ ʋ a m u ɭ ɭ a',
#  'അംഗത്വവും': 'a m ɡ a t̪ ʋ a ʋ u m',
#  'അംഗദൻ': 'a m ɡ a d̪ a n',
#  'അംഗനവാടി': 'a m ɡ a n a ʋ aː ʈ i',
#  'അംഗൻവാടി': 'a m ɡ a n ʋ aː ʈ i',
#  'അംഗബലം': 'a m ɡ a b a l a m',
#  'അംഗഭംഗം': 'a m ɡ a bʱ a m ɡ a m',
#  'അംഗമല്ലാത്ത': 'a m ɡ a m a l l aː t̪ t̪ a',
#  'അംഗമാകാൻ': 'a m ɡ a m aː k aː n',
#  'അംഗമാണെന്ന്': 'a m ɡ a m aː ɳ e n̪ n̪ ə',
#  'അംഗമാണ്': 'a m ɡ a m aː ɳ ə',
#  'അംഗമായ': 'a m ɡ a m aː j a',
#  'അംഗമായി': 'a m ɡ a m aː j i',
#  'അംഗമായിട്ടുണ്ട്': 'a m ɡ a m aː j i ʈ ʈ u ɳ ʈ ə',
#  'അംഗമായിരിക്കും': 'a m ɡ a m aː j i ɾ i k k u m',
#  'അംഗമായിരുന്ന': 'a m ɡ a m aː j i ɾ u n̪ n̪ a',
#  'അംഗമായിരുന്നിട്ടുണ്ട്': 'a m ɡ a m aː j i ɾ u n̪ n̪ i ʈ ʈ u ɳ ʈ ə',
#  'അംഗമായിരുന്നു': 'a m ɡ a m aː j i ɾ u n̪ n̪ u',
#  'അംഗമായും': 'a m ɡ a m aː j u m',
#  'അംഗമായുള്ള': 'a m ɡ a m aː j u ɭ ɭ a',
#  'അംഗമാവുകയും': 'a m ɡ a m aː ʋ u k a j u m',
#  'അംഗമെന്ന': 'a m ɡ a m e n̪ n̪ a',
#  'അഗര': 'a ɡ a ɾ a',
#  'അംഗരക്ഷകന്റെ': 'a m ɡ a ɾ a k ʂ a k a n ṯ e',
#  'അംഗരാജ്യങ്ങളുടെ': 'a m ɡ a ɾ aː ɟ j a ŋ ŋ a ɭ u ʈ e',
#  'അംഗരാജ്യങ്ങളുമായി': 'a m ɡ a ɾ aː ɟ j a ŋ ŋ a ɭ u m aː j i',
#  'അംഗരാജ്യങ്ങൾ': 'a m ɡ a ɾ aː ɟ j a ŋ ŋ a ɭ',
#  'അഗർ': 'a ɡ a r',
#  'അഗർവാളിനെ': 'a ɡ a r ʋ aː ɭ i n e',
#  'അഗർവാളിന്റെ': 'a ɡ a r ʋ aː ɭ i n ṯ e',
#  'അഗർവാളും': 'a ɡ a r ʋ aː ɭ u m',
#  'അഗർവാൾ': 'a ɡ a r ʋ aː ɭ',
#  'അംഗവിക്ഷേപങ്ങളാലും': 'a m ɡ a ʋ i k ʂ eː p a ŋ ŋ a ɭ aː l u m',
#  'അംഗവും': 'a m ɡ a ʋ u m',
#  'അംഗവുമാണ്': 'a m ɡ a ʋ u m aː ɳ ə',
#  'അംഗവുമായ': 'a m ɡ a ʋ u m aː j a',
#  'അംഗവുമായിരുന്ന': 'a m ɡ a ʋ u m aː j i ɾ u n̪ n̪ a',
#  'അംഗവുമായിരുന്നു': 'a m ɡ a ʋ u m aː j i ɾ u n̪ n̪ u',
#  'അംഗവൈകല്യം': 'a m ɡ a ʋ ai̯ k a l j a m',
#  'അംഗവൈകല്യമുള്ളവരെ': 'a m ɡ a ʋ ai̯ k a l j a m u ɭ ɭ a ʋ a ɾ e',
#  'അംഗസംഖ്യ': 'a m ɡ a s a m kʰ j a',
#  'അഗസ്ത': 'a ɡ a s t̪ a',
#  'അഗസ്തീനോസിന്റെ': 'a ɡ a s t̪ iː n oː s i n ṯ e',
#  'അഗസ്തീനോസ്': 'a ɡ a s t̪ iː n oː s ə',
#  'അഗസ്തീശ്വരം': 'a ɡ a s t̪ iː ʋ a ɾ a m',
#  'അഗസ്തോസിന്റെ': 'a ɡ a s t̪ oː s i n ṯ e',
#  'അഗസ്ത്യ': 'a ɡ a s t̪ j a',
#  'അഗസ്ത്യകൂടം': 'a ɡ a s t̪ j a k uː ʈ a m',
#  'അഗസ്ത്യൻ': 'a ɡ a s t̪ j a n',
#  'അഗസ്ത്യമല': 'a ɡ a s t̪ j a m a l a',
#  'അഗസ്റ്റ': 'a ɡ a s ṯ ṯ a',
#  'അഗസ്റ്റയുടെ': 'a ɡ a s ṯ ṯ a j u ʈ e',
#  'അഗസ്റ്റസ്': 'a ɡ a s ṯ ṯ a s ə',
#  'അഗസ്റ്റിൻ': 'a ɡ a s ṯ ṯ i n',
#  'അഗസ്റ്റിന്റെ': 'a ɡ a s ṯ ṯ i n ṯ e',
#  'അഗസ്റ്റ്യൻ': 'a ɡ a s ṯ ṯ j a n',
#  'അഗളി': 'a ɡ a ɭ i',
#  'അഗാതമായ': 'a ɡ aː t̪ a m aː j a',
#  'അഗാധ': 'a ɡ aː d̪ʱ a',
#  'അഗാധതയിൽ': 'a ɡ aː d̪ʱ a t̪ a j i l',
#  'അഗാധമായ': 'a ɡ aː d̪ʱ a m aː j a',
#  'അഗാധമായി': 'a ɡ aː d̪ʱ a m aː j i',
#  'അഗാർക്കർ': 'a ɡ aː r k k a r',
#  'അംഗിരസ്സ്': 'a m ɡ i ɾ a s s ə',
#  'അംഗീകരിക്കണം': 'a m ɡ iː k a ɾ i k k a ɳ a m',
#  'അംഗീകരിക്കണമെന്നും': 'a m ɡ iː k a ɾ i k k a ɳ a m e n̪ n̪ u m',
#  'അംഗീകരിക്കണമെന്ന്': 'a m ɡ iː k a ɾ i k k a ɳ a m e n̪ n̪ ə',
#  'അംഗീകരിക്കപ്പെടുകയും': 'a m ɡ iː k a ɾ i k k a p p e ʈ u k a j u m',
#  'അംഗീകരിക്കപ്പെടുന്നു': 'a m ɡ iː k a ɾ i k k a p p e ʈ u n̪ n̪ u',
#  'അംഗീകരിക്കപ്പെട്ട': 'a m ɡ iː k a ɾ i k k a p p e ʈ ʈ a',
#  'അംഗീകരിക്കപ്പെട്ടത്': 'a m ɡ iː k a ɾ i k k a p p e ʈ ʈ a t̪ ə',
#  'അംഗീകരിക്കപ്പെട്ടിട്ടില്ല': 'a m ɡ iː k a ɾ i k k a p p e ʈ ʈ i ʈ ʈ i l l a',
#  'അംഗീകരിക്കപ്പെട്ടിട്ടുണ്ട്': 'a m ɡ iː k a ɾ i k k a p p e ʈ ʈ i ʈ ʈ u ɳ ʈ ə',
#  'അംഗീകരിക്കപ്പെട്ടിരിക്കുന്നത്': 'a m ɡ iː k a ɾ i k k a p p e ʈ ʈ i ɾ i k k u n̪ n̪ a t̪ ə',
#  'അംഗീകരിക്കപ്പെട്ടു': 'a m ɡ iː k a ɾ i k k a p p e ʈ ʈ u',
#  'അംഗീകരിക്കരുത്': 'a m ɡ iː k a ɾ i k k a ɾ u t̪ ə',
#  'അംഗീകരിക്കാം': 'a m ɡ iː k a ɾ i k k aː m',
#  'അംഗീകരിക്കാതെ': 'a m ɡ iː k a ɾ i k k aː t̪ e',
#  'അംഗീകരിക്കാത്ത': 'a m ɡ iː k a ɾ i k k aː t̪ t̪ a',
#  'അംഗീകരിക്കാനാകില്ല': 'a m ɡ iː k a ɾ i k k aː n aː k i l l a',
#  'അംഗീകരിക്കാനാകില്ലെന്നും': 'a m ɡ iː k a ɾ i k k aː n aː k i l l e n̪ n̪ u m',
#  'അംഗീകരിക്കാനാകില്ലെന്ന്': 'a m ɡ iː k a ɾ i k k aː n aː k i l l e n̪ n̪ ə',
#  'അംഗീകരിക്കാനാവില്ല': 'a m ɡ iː k a ɾ i k k aː n aː ʋ i l l a',
#  'അംഗീകരിക്കാനാവില്ലെന്നും': 'a m ɡ iː k a ɾ i k k aː n aː ʋ i l l e n̪ n̪ u m',
#  'അംഗീകരിക്കാനാവില്ലെന്ന്': 'a m ɡ iː k a ɾ i k k aː n aː ʋ i l l e n̪ n̪ ə',
#  'അംഗീകരിക്കാനും': 'a m ɡ iː k a ɾ i k k aː n u m',
#  'അംഗീകരിക്കാനുള്ള': 'a m ɡ iː k a ɾ i k k aː n u ɭ ɭ a',
#  'അംഗീകരിക്കാനോ': 'a m ɡ iː k a ɾ i k k aː n oː',
#  'അംഗീകരിക്കാൻ': 'a m ɡ iː k a ɾ i k k aː n',
#  'അംഗീകരിക്കാവൂ': 'a m ɡ iː k a ɾ i k k aː ʋ uː',
#  'അംഗീകരിക്കില്ല': 'a m ɡ iː k a ɾ i k k i l l a',
#  'അംഗീകരിക്കില്ലെന്നു': 'a m ɡ iː k a ɾ i k k i l l e n̪ n̪ u',
#  'അംഗീകരിക്കില്ലെന്നും': 'a m ɡ iː k a ɾ i k k i l l e n̪ n̪ u m',
#  'അംഗീകരിക്കില്ലെന്നുമായി': 'a m ɡ iː k a ɾ i k k i l l e n̪ n̪ u m aː j i',
#  'അംഗീകരിക്കില്ലെന്ന്': 'a m ɡ iː k a ɾ i k k i l l e n̪ n̪ ə',
#  'അംഗീകരിക്കും': 'a m ɡ iː k a ɾ i k k u m',
#  'അംഗീകരിക്കുക': 'a m ɡ iː k a ɾ i k k u k a',
#  'അംഗീകരിക്കുകയാണ്': 'a m ɡ iː k a ɾ i k k u k a j aː ɳ ə',
#  'അംഗീകരിക്കുകയായിരുന്നു': 'a m ɡ iː k a ɾ i k k u k a j aː j i ɾ u n̪ n̪ u',
#  'അംഗീകരിക്കുകയും': 'a m ɡ iː k a ɾ i k k u k a j u m',
#  'അംഗീകരിക്കുകയോ': 'a m ɡ iː k a ɾ i k k u k a j oː',
#  'അംഗീകരിക്കുന്ന': 'a m ɡ iː k a ɾ i k k u n̪ n̪ a',
#  'അംഗീകരിക്കുന്നതാണ്': 'a m ɡ iː k a ɾ i k k u n̪ n̪ a t̪ aː ɳ ə',
#  'അംഗീകരിക്കുന്നതിന്': 'a m ɡ iː k a ɾ i k k u n̪ n̪ a t̪ i n ə',
#  'അംഗീകരിക്കുന്നതോടെ': 'a m ɡ iː k a ɾ i k k u n̪ n̪ a t̪ oː ʈ e',
#  'അംഗീകരിക്കുന്നത്': 'a m ɡ iː k a ɾ i k k u n̪ n̪ a t̪ ə',
#  'അംഗീകരിക്കുന്നില്ല': 'a m ɡ iː k a ɾ i k k u n̪ n̪ i l l a',
#  'അംഗീകരിക്കുന്നു': 'a m ɡ iː k a ɾ i k k u n̪ n̪ u',
#  'അംഗീകരിക്കുന്നുണ്ട്': 'a m ɡ iː k a ɾ i k k u n̪ n̪ u ɳ ʈ ə',
#  'അംഗീകരിക്കുന്നുവെന്ന്': 'a m ɡ iː k a ɾ i k k u n̪ n̪ u ʋ e n̪ n̪ ə',
#  'അംഗീകരിക്കുന്നെന്ന്': 'a m ɡ iː k a ɾ i k k u n̪ n̪ e n̪ n̪ ə',
#  'അംഗീകരിക്കുമെന്നും': 'a m ɡ iː k a ɾ i k k u m e n̪ n̪ u m',
#  'അംഗീകരിക്കുമെന്ന്': 'a m ɡ iː k a ɾ i k k u m e n̪ n̪ ə',
#  'അംഗീകരിക്കുമോ': 'a m ɡ iː k a ɾ i k k u m oː',
#  'അംഗീകരിക്കുമ്പോൾ': 'a m ɡ iː k a ɾ i k k u m p oː ɭ',
#  'അംഗീകരിക്കുവാൻ': 'a m ɡ iː k a ɾ i k k u ʋ aː n',
#  'അംഗീകരിക്കേണ്ടി': 'a m ɡ iː k a ɾ i k k eː ɳ ʈ i',
#  'അംഗീകരിച്ച': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ a',
#  'അംഗീകരിച്ചതാണ്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ a t̪ aː ɳ ə',
#  'അംഗീകരിച്ചതായി': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ a t̪ aː j i',
#  'അംഗീകരിച്ചതോടെ': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ a t̪ oː ʈ e',
#  'അംഗീകരിച്ചത്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ a t̪ ə',
#  'അംഗീകരിച്ചാണ്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ aː ɳ ə',
#  'അംഗീകരിച്ചാൽ': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ aː l',
#  'അംഗീകരിച്ചിട്ടില്ല': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i ʈ ʈ i l l a',
#  'അംഗീകരിച്ചിട്ടുണ്ട്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i ʈ ʈ u ɳ ʈ ə',
#  'അംഗീകരിച്ചിട്ടുള്ള': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i ʈ ʈ u ɭ ɭ a',
#  'അംഗീകരിച്ചിരിക്കുന്നത്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i ɾ i k k u n̪ n̪ a t̪ ə',
#  'അംഗീകരിച്ചിരിക്കുന്നു': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i ɾ i k k u n̪ n̪ u',
#  'അംഗീകരിച്ചിരുന്നില്ല': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i ɾ u n̪ n̪ i l l a',
#  'അംഗീകരിച്ചിരുന്നു': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i ɾ u n̪ n̪ u',
#  'അംഗീകരിച്ചില്ല': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i l l a',
#  'അംഗീകരിച്ചില്ലെങ്കിൽ': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ i l l e ŋ k i l',
#  'അംഗീകരിച്ചു': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ u',
#  'അംഗീകരിച്ചുകൊണ്ടാണ്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ u k o ɳ ʈ aː ɳ ə',
#  'അംഗീകരിച്ചുകൊണ്ട്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ u k o ɳ ʈ ə',
#  'അംഗീകരിച്ചെങ്കിലും': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ e ŋ k i l u m',
#  'അംഗീകരിച്ചേ': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ eː',
#  'അംഗീകരിച്ച്': 'a m ɡ iː k a ɾ i t͡ʃ t͡ʃ ə',
#  'അംഗീകരിയ്ക്കാൻ': 'a m ɡ iː k a ɾ i j k k aː n',
#  'അംഗീകാര': 'a m ɡ iː k aː ɾ a',
#  'അംഗീകാരം': 'a m ɡ iː k aː ɾ a m',
#  'അംഗീകാരങ്ങളും': 'a m ɡ iː k aː ɾ a ŋ ŋ a ɭ u m',
#  'അംഗീകാരങ്ങൾ': 'a m ɡ iː k aː ɾ a ŋ ŋ a ɭ',
#  'അംഗീകാരത്തിനായി': 'a m ɡ iː k aː ɾ a t̪ t̪ i n aː j i',
#  'അംഗീകാരത്തിന്': 'a m ɡ iː k aː ɾ a t̪ t̪ i n ə',
#  'അംഗീകാരത്തിന്റെ': 'a m ɡ iː k aː ɾ a t̪ t̪ i n ṯ e',
#  'അംഗീകാരത്തോടെ': 'a m ɡ iː k aː ɾ a t̪ t̪ oː ʈ e',
#  'അംഗീകാരമാണ്': 'a m ɡ iː k aː ɾ a m aː ɳ ə',
#  'അംഗീകാരമായാണ്': 'a m ɡ iː k aː ɾ a m aː j aː ɳ ə',
#  'അംഗീകാരമായി': 'a m ɡ iː k aː ɾ a m aː j i',
#  'അംഗീകാരമില്ലാതെ': 'a m ɡ iː k aː ɾ a m i l l aː t̪ e',
#  'അംഗീകാരമില്ലാത്ത': 'a m ɡ iː k aː ɾ a m i l l aː t̪ t̪ a',
#  'അംഗീകാരമുണ്ട്': 'a m ɡ iː k aː ɾ a m u ɳ ʈ ə',
#  'അംഗീകാരമുള്ള': 'a m ɡ iː k aː ɾ a m u ɭ ɭ a',
#  'അംഗീകാരമോ': 'a m ɡ iː k aː ɾ a m oː',
#  'അംഗീകാരവും': 'a m ɡ iː k aː ɾ a ʋ u m',
#  'അംഗീകൃത': 'a m ɡ iː k rɨ t̪ a',
#  'അംഗീകൃതമായ': 'a m ɡ iː k rɨ t̪ a m aː j a',
#  'അഗുങ്': 'a ɡ u ŋ ə',
#  'അഗ്നി': 'a ɡ n i',
#  'അഗ്നിക്കിരയാക്കി': 'a ɡ n i k k i ɾ a j aː k k i',
#  'അഗ്നിക്കിരയാക്കുകയും': 'a ɡ n i k k i ɾ a j aː k k u k a j u m',
#  'അഗ്നിക്കിരയായത്': 'a ɡ n i k k i ɾ a j aː j a t̪ ə',
#  'അഗ്നിജ്വാലയായി': 'a ɡ n i ɟ ʋ aː l a j aː j i',
#  'അഗ്നിപരീക്ഷ': 'a ɡ n i p a ɾ iː k ʂ a',
#  'അഗ്നിപർവത': 'a ɡ n i p a r ʋ a t̪ a',
#  'അഗ്നിപർവതം': 'a ɡ n i p a r ʋ a t̪ a m',
#  'അഗ്നിപർവ്വത': 'a ɡ n i p a r ʋ ʋ a t̪ a',
#  'അഗ്നിപർവ്വതം': 'a ɡ n i p a r ʋ ʋ a t̪ a m',
#  'അഗ്നിപർവ്വതങ്ങളുടെ': 'a ɡ n i p a r ʋ ʋ a t̪ a ŋ ŋ a ɭ u ʈ e',
#  'അഗ്നിപർവ്വതങ്ങൾ': 'a ɡ n i p a r ʋ ʋ a t̪ a ŋ ŋ a ɭ',
#  'അഗ്നിപർവ്വതത്തിന്റെ': 'a ɡ n i p a r ʋ ʋ a t̪ a t̪ t̪ i n ṯ e',
#  'അഗ്നിപർവ്വതമായ': 'a ɡ n i p a r ʋ ʋ a t̪ a m aː j a',
#  'അഗ്നിപുരാണം': 'a ɡ n i p u ɾ aː ɳ a m',
#  'അഗ്നിബാധ': 'a ɡ n i b aː d̪ʱ a',
#  'അഗ്നിബാധയിൽ': 'a ɡ n i b aː d̪ʱ a j i l',
#  'അഗ്നിമാന്ദ്യം': 'a ɡ n i m aː n̪ d̪ j a m',
#  'അഗ്നിയിൽ': 'a ɡ n i j i l',
#  'അഗ്നിയും': 'a ɡ n i j u m',
#  'അഗ്നിയുടെ': 'a ɡ n i j u ʈ e',
#  'അഗ്നിയെ': 'a ɡ n i j e',
#  'അഗ്നിയേയും': 'a ɡ n i j eː j u m',
#  'അഗ്നിരക്ഷാ': 'a ɡ n i ɾ a k ʂ aː',
#  'അഗ്നിവേശ്': 'a ɡ n i ʋ eː ə',
#  'അഗ്നിശമന': 'a ɡ n i a m a n a',
#  'അഗ്നിശമനസേന': 'a ɡ n i a m a n a s eː n a',
#  'അഗ്നിശമനസേനയെ': 'a ɡ n i a m a n a s eː n a j e',
#  'അഗ്നിശമനസേനാ': 'a ɡ n i a m a n a s eː n aː',
#  'അഗ്നിശുദ്ധി': 'a ɡ n i u d̪ d̪ʱ i',
#  'അഗ്നിസാക്ഷി': 'a ɡ n i s aː k ʂ i',
#  'അഗ്നിസാരക്രിയ': 'a ɡ n i s aː ɾ a k r i j a',
#  'അഗ്നിഹോത്രി': 'a ɡ n i ɦ oː t̪ r i',
#  'അഗ്നിഹോത്രിയുടെ': 'a ɡ n i ɦ oː t̪ r i j u ʈ e',
#  'അഗ്യൂറോ': 'a ɡ j uː r oː',
#  'അഗ്ര': 'a ɡ ɾ a',
#  'അഗ്രം': 'a ɡ ɾ a m',
#  'അഗ്രങ്ങൾ': 'a ɡ ɾ a ŋ ŋ a ɭ',
#  'അഗ്രജൻ': 'a ɡ ɾ a ɟ a n',
#  'അഗ്രജാ': 'a ɡ ɾ a ɟ aː',
#  'അഗ്രത്തിൽ': 'a ɡ ɾ a t̪ t̪ i l',
#  'അഗ്രഭാഗം': 'a ɡ ɾ a bʱ aː ɡ a m',
#  'അഗ്രഭാഗത്ത്': 'a ɡ ɾ a bʱ aː ɡ a t̪ t̪ ə',
#  'അഗ്രഹാര': 'a ɡ ɾ a ɦ aː ɾ a',
#  'അഗ്രി': 'a ɡ ɾ i',
#  'അഗ്രികൾച്ചർ': 'a ɡ ɾ i k a ɭ t͡ʃ t͡ʃ a r',
#  'അഗ്രികൾച്ചറൽ': 'a ɡ ɾ i k a ɭ t͡ʃ t͡ʃ a r a l',
#  'അഗ്രിക്കൾച്ചർ': 'a ɡ ɾ i k k a ɭ t͡ʃ t͡ʃ a r',
#  'അഗ്രിക്കൾച്ചറൽ': 'a ɡ ɾ i k k a ɭ t͡ʃ t͡ʃ a r a l',
#  'അഗ്രിക്കോള': 'a ɡ ɾ i k k oː ɭ a',
#  'അഗ്രിഗേറ്റർ': 'a ɡ ɾ i ɡ eː ṯ ṯ a r',
#  'അഗ്രോ': 'a ɡ ɾ oː',
#  'അഗ്വാർ': 'a ɡ ʋ aː r',
#  'അഘ്രാണത': 'a ɡʱ r aː ɳ a t̪ a',
#  'അങനെ': 'a ŋ a n e',
#  'അങൽ': 'a ŋ a l',
#  'അങിനെ': 'a ŋ i n e',
#  'അങ്കം': 'a ŋ k a m',
#  'അങ്കക്കാരൻ': 'a ŋ k a k k aː ɾ a n',
#  'അങ്കണം': 'a ŋ k a ɳ a m',
#  'അങ്കണത്തിനു': 'a ŋ k a ɳ a t̪ t̪ i n u',
#  'അങ്കണത്തിലെ': 'a ŋ k a ɳ a t̪ t̪ i l e',
#  'അങ്കണത്തിൽ': 'a ŋ k a ɳ a t̪ t̪ i l',
#  'അങ്കണവാടി': 'a ŋ k a ɳ a ʋ aː ʈ i',
#  'അങ്കണവാടികളിൽ': 'a ŋ k a ɳ a ʋ aː ʈ i k a ɭ i l',
#  'അങ്കണവാടികൾ': 'a ŋ k a ɳ a ʋ aː ʈ i k a ɭ',
#  'അങ്കണവാടിയിലും': 'a ŋ k a ɳ a ʋ aː ʈ i j i l u m',
#  'അങ്കൺവാടി': 'a ŋ k a ɳ ʋ aː ʈ i',
#  'അങ്കത്തിന്': 'a ŋ k a t̪ t̪ i n ə',
#  'അങ്കത്തിൽ': 'a ŋ k a t̪ t̪ i l',
#  'അങ്കമാലി': 'a ŋ k a m aː l i',
#  'അങ്കമാലിയിലെ': 'a ŋ k a m aː l i j i l e',
#  'അങ്കമാലിയിൽ': 'a ŋ k a m aː l i j i l',
#  'അങ്കലാപ്പ്': 'a ŋ k a l aː p p ə',
#  'അങ്കി': 'a ŋ k i',
#  'അങ്കിത്': 'a ŋ k i t̪ ə',
#  'അങ്കിളിന്റെ': 'a ŋ k i ɭ i n ṯ e',
#  'അങ്കിളേ': 'a ŋ k i ɭ eː',
#  'അങ്കിൾ': 'a ŋ k i ɭ',
#  'അങ്കോർ': 'a ŋ k oː r',
#  'അങ്ങകലെ': 'a ŋ ŋ a k a l e',
#  'അങ്ങട്': 'a ŋ ŋ a ʈ ə',
#  'അങ്ങട്ട്': 'a ŋ ŋ a ʈ ʈ ə',
#  'അങ്ങനത്തെ': 'a ŋ ŋ a n a t̪ t̪ e',
#  'അങ്ങനെ': 'a ŋ ŋ a n e',
#  'അങ്ങനെതന്നെ': 'a ŋ ŋ a n e t̪ a n̪ n̪ e',
#  'അങ്ങനെത്തന്നെ': 'a ŋ ŋ a n e t̪ t̪ a n̪ n̪ e',
#  'അങ്ങനെയങ്ങനെ': 'a ŋ ŋ a n e j a ŋ ŋ a n e',
#  'അങ്ങനെയങ്ങ്': 'a ŋ ŋ a n e j a ŋ ŋ ə',
#  'അങ്ങനെയല്ല': 'a ŋ ŋ a n e j a l l a',
#  'അങ്ങനെയാ': 'a ŋ ŋ a n e j aː',
#  'അങ്ങനെയാണു': 'a ŋ ŋ a n e j aː ɳ u',
#  'അങ്ങനെയാണെങ്കിൽ': 'a ŋ ŋ a n e j aː ɳ e ŋ k i l',
#  'അങ്ങനെയാണ്': 'a ŋ ŋ a n e j aː ɳ ə',
#  'അങ്ങനെയായാൽ': 'a ŋ ŋ a n e j aː j aː l',
#  'അങ്ങനെയാവുന്പോൾ': 'a ŋ ŋ a n e j aː ʋ u n̪ p oː ɭ',
#  'അങ്ങനെയിരിക്കെ': 'a ŋ ŋ a n e j i ɾ i k k e',
#  'അങ്ങനെയിരിക്കെയാണ്': 'a ŋ ŋ a n e j i ɾ i k k e j aː ɳ ə',
#  'അങ്ങനെയും': 'a ŋ ŋ a n e j u m',
#  'അങ്ങനെയുള്ള': 'a ŋ ŋ a n e j u ɭ ɭ a',
#  'അങ്ങനെയുള്ളവർ': 'a ŋ ŋ a n e j u ɭ ɭ a ʋ a r',
#  'അങ്ങനെയെങ്കിലും': 'a ŋ ŋ a n e j e ŋ k i l u m',
#  'അങ്ങനെയെങ്കിൽ': 'a ŋ ŋ a n e j e ŋ k i l',
#  'അങ്ങനെയൊക്കെ': 'a ŋ ŋ a n e j o k k e',
#  'അങ്ങനെയൊക്കെയാണ്': 'a ŋ ŋ a n e j o k k e j aː ɳ ə',
#  'അങ്ങനെയൊന്നും': 'a ŋ ŋ a n e j o n̪ n̪ u m',
#  'അങ്ങനെയൊന്ന്': 'a ŋ ŋ a n e j o n̪ n̪ ə',
#  'അങ്ങനെയൊരു': 'a ŋ ŋ a n e j o ɾ u',
#  'അങ്ങനൊരു': 'a ŋ ŋ a n o ɾ u',
#  'അങ്ങയുടെ': 'a ŋ ŋ a j u ʈ e',
#  'അങ്ങയെ': 'a ŋ ŋ a j e',
#  'അങ്ങാടി': 'a ŋ ŋ aː ʈ i',
#  'അങ്ങാടിക്കടവ്': 'a ŋ ŋ aː ʈ i k k a ʈ a ʋ ə',
#  'അങ്ങാടിക്കൽ': 'a ŋ ŋ aː ʈ i k k a l',
#  'അങ്ങാടിപ്പുറം': 'a ŋ ŋ aː ʈ i p p u r a m',
#  'അങ്ങാടിപ്പുറത്ത്': 'a ŋ ŋ aː ʈ i p p u r a t̪ t̪ ə',
#  'അങ്ങാടിയത്ത്': 'a ŋ ŋ aː ʈ i j a t̪ t̪ ə',
#  'അങ്ങാടിയിലെ': 'a ŋ ŋ aː ʈ i j i l e',
#  'അങ്ങാടിയിൽ': 'a ŋ ŋ aː ʈ i j i l',
#  'അങ്ങിങ്ങായി': 'a ŋ ŋ i ŋ ŋ aː j i',
#  'അങ്ങിങ്ങ്': 'a ŋ ŋ i ŋ ŋ ə',
#  'അങ്ങിനെ': 'a ŋ ŋ i n e',
#  'അങ്ങിനെയങ്ങിനെ': 'a ŋ ŋ i n e j a ŋ ŋ i n e',
#  'അങ്ങിനെയല്ല': 'a ŋ ŋ i n e j a l l a',
#  'അങ്ങിനെയാണെങ്കിൽ': 'a ŋ ŋ i n e j aː ɳ e ŋ k i l',
#  'അങ്ങിനെയാണ്': 'a ŋ ŋ i n e j aː ɳ ə',
#  'അങ്ങിനെയിരിക്കെ': 'a ŋ ŋ i n e j i ɾ i k k e',
#  'അങ്ങിനെയുള്ള': 'a ŋ ŋ i n e j u ɭ ɭ a',
#  'അങ്ങിനെയെങ്കിൽ': 'a ŋ ŋ i n e j e ŋ k i l',
#  'അങ്ങിനെയൊക്കെ': 'a ŋ ŋ i n e j o k k e',
#  'അങ്ങിനെയൊരു': 'a ŋ ŋ i n e j o ɾ u',
#  'അങ്ങിപ്പോൾ': 'a ŋ ŋ i p p oː ɭ',
#  'അങ്ങു': 'a ŋ ŋ u',
#  'അങ്ങും': 'a ŋ ŋ u m',
#  'അങ്ങുന്നേ': 'a ŋ ŋ u n̪ n̪ eː',
#  'അങ്ങുമിങ്ങും': 'a ŋ ŋ u m i ŋ ŋ u m',
#  'അങ്ങെത്തിക്കോളാം': 'a ŋ ŋ e t̪ t̪ i k k oː ɭ aː m',
#  'അങ്ങേ': 'a ŋ ŋ eː',
#  'അങ്ങേക്ക്': 'a ŋ ŋ eː k k ə',
#  'അങ്ങേത്തലയ്ക്കൽ': 'a ŋ ŋ eː t̪ t̪ a l a j k k a l',
#  'അങ്ങേയറ്റം': 'a ŋ ŋ eː j a ṯ ṯ a m',
#  'അങ്ങേയറ്റത്തെ': 'a ŋ ŋ eː j a ṯ ṯ a t̪ t̪ e',
#  'അങ്ങേയ്ക്കൂഹിക്കാവുന്നതേയുള്ളൂ': 'a ŋ ŋ eː j k k uː ɦ i k k aː ʋ u n̪ n̪ a t̪ eː j u ɭ ɭ uː',
#  'അങ്ങേയ്ക്ക്': 'a ŋ ŋ eː j k k ə',
#  'അങ്ങേരു': 'a ŋ ŋ eː ɾ u',
#  'അങ്ങേരുടെ': 'a ŋ ŋ eː ɾ u ʈ e',
#  'അങ്ങേരെ': 'a ŋ ŋ eː ɾ e',
#  'അങ്ങേര്': 'a ŋ ŋ eː ɾ ə',
#  'അങ്ങേർ': 'a ŋ ŋ eː r',
#  'അങ്ങേർക്കു': 'a ŋ ŋ eː r k k u',
#  'അങ്ങേർക്ക്': 'a ŋ ŋ eː r k k ə',
#  'അങ്ങോട്ടു': 'a ŋ ŋ oː ʈ ʈ u',
#  'അങ്ങോട്ടും': 'a ŋ ŋ oː ʈ ʈ u m',
#  'അങ്ങോട്ടുമിങ്ങോട്ടും': 'a ŋ ŋ oː ʈ ʈ u m i ŋ ŋ oː ʈ ʈ u m',
#  'അങ്ങോട്ടുള്ള': 'a ŋ ŋ oː ʈ ʈ u ɭ ɭ a',
#  'അങ്ങോട്ടെത്തിയിരുന്നു': 'a ŋ ŋ oː ʈ ʈ e t̪ t̪ i j i ɾ u n̪ n̪ u',
#  'അങ്ങോട്ടേക്ക്': 'a ŋ ŋ oː ʈ ʈ eː k k ə',
#  'അങ്ങോട്ട്': 'a ŋ ŋ oː ʈ ʈ ə',
#  'അങ്ങോളമിങ്ങോളം': 'a ŋ ŋ oː ɭ a m i ŋ ŋ oː ɭ a m',
#  'അങ്ങ്': 'a ŋ ŋ ə',
#  'അചഞ്ചലമായ': 'a t͡ʃ a ɲ t͡ʃ a l a m aː j a',
#  'അച്': 'a t͡ʃ ə',
#  'അച്ചടക്ക': 'a t͡ʃ t͡ʃ a ʈ a k k a',
#  'അച്ചടക്കം': 'a t͡ʃ t͡ʃ a ʈ a k k a m',
#  'അച്ചടക്കത്തിന്റെ': 'a t͡ʃ t͡ʃ a ʈ a k k a t̪ t̪ i n ṯ e',
#  'അച്ചടക്കത്തിലൂന്നിയതും': 'a t͡ʃ t͡ʃ a ʈ a k k a t̪ t̪ i l uː n̪ n̪ i j a t̪ u m',
#  'അച്ചടക്കത്തോടെ': 'a t͡ʃ t͡ʃ a ʈ a k k a t̪ t̪ oː ʈ e',
#  'അച്ചടക്കനടപടി': 'a t͡ʃ t͡ʃ a ʈ a k k a n a ʈ a p a ʈ i',
#  'അച്ചടക്കനടപടികളിൽ': 'a t͡ʃ t͡ʃ a ʈ a k k a n a ʈ a p a ʈ i k a ɭ i l',
#  'അച്ചടക്കമില്ലാത്ത': 'a t͡ʃ t͡ʃ a ʈ a k k a m i l l aː t̪ t̪ a',
#  'അച്ചടക്കമുള്ള': 'a t͡ʃ t͡ʃ a ʈ a k k a m u ɭ ɭ a',
#  'അച്ചടക്കലംഘനം': 'a t͡ʃ t͡ʃ a ʈ a k k a l a m ɡʱ a n a m',
#  'അച്ചടക്കവും': 'a t͡ʃ t͡ʃ a ʈ a k k a ʋ u m',
#  'അച്ചടി': 'a t͡ʃ t͡ʃ a ʈ i',
#  'അച്ചടിക്കാൻ': 'a t͡ʃ t͡ʃ a ʈ i k k aː n',
#  'അച്ചടിക്കുന്ന': 'a t͡ʃ t͡ʃ a ʈ i k k u n̪ n̪ a',
#  'അച്ചടിച്ച': 'a t͡ʃ t͡ʃ a ʈ i t͡ʃ t͡ʃ a',
#  'അച്ചടിച്ചത്': 'a t͡ʃ t͡ʃ a ʈ i t͡ʃ t͡ʃ a t̪ ə',
#  'അച്ചടിച്ചിരിക്കുന്നത്': 'a t͡ʃ t͡ʃ a ʈ i t͡ʃ t͡ʃ i ɾ i k k u n̪ n̪ a t̪ ə',
#  'അച്ചടിച്ചു': 'a t͡ʃ t͡ʃ a ʈ i t͡ʃ t͡ʃ u',
#  'അച്ചടിച്ചുവന്നത്': 'a t͡ʃ t͡ʃ a ʈ i t͡ʃ t͡ʃ u ʋ a n̪ n̪ a t̪ ə',
#  'അച്ചടിച്ച്': 'a t͡ʃ t͡ʃ a ʈ i t͡ʃ t͡ʃ ə',
#  'അച്ചടിമഷി': 'a t͡ʃ t͡ʃ a ʈ i m a ʂ i',
#  'അച്ചടിയന്ത്രം': 'a t͡ʃ t͡ʃ a ʈ i j a n̪ t̪ r a m',
#  'അച്ചടിയന്ത്രങ്ങളുമായി': 'a t͡ʃ t͡ʃ a ʈ i j a n̪ t̪ r a ŋ ŋ a ɭ u m aː j i',
#  'അച്ചടിയിൽ': 'a t͡ʃ t͡ʃ a ʈ i j i l',
#  'അച്ചടിയും': 'a t͡ʃ t͡ʃ a ʈ i j u m',
#  'അച്ചടിയുടെ': 'a t͡ʃ t͡ʃ a ʈ i j u ʈ e',
#  'അച്ചടിശാല': 'a t͡ʃ t͡ʃ a ʈ i aː l a',
#  'അച്ചടിശാലകളൊന്നും': 'a t͡ʃ t͡ʃ a ʈ i aː l a k a ɭ o n̪ n̪ u m',
#  'അച്ചനും': 'a t͡ʃ t͡ʃ a n u m',
#  'അച്ചനെ': 'a t͡ʃ t͡ʃ a n e',
#  'അച്ചന്': 'a t͡ʃ t͡ʃ a n ə',
#  'അച്ചൻ': 'a t͡ʃ t͡ʃ a n',
#  'അച്ചൻകുഞ്ഞ്': 'a t͡ʃ t͡ʃ a n k u ɲ ɲ ə',
#  'അച്ചൻകോവിലാർ': 'a t͡ʃ t͡ʃ a n k oː ʋ i l aː r',
#  'അച്ചൻകോവിലാറും': 'a t͡ʃ t͡ʃ a n k oː ʋ i l aː r u m',
#  'അച്ചൻകോവിൽ': 'a t͡ʃ t͡ʃ a n k oː ʋ i l',
#  'അച്ചന്മാരും': 'a t͡ʃ t͡ʃ a n m aː ɾ u m',
#  'അച്ചന്മാരുടെ': 'a t͡ʃ t͡ʃ a n m aː ɾ u ʈ e',
#  'അച്ചന്മാർ': 'a t͡ʃ t͡ʃ a n m aː r',
#  'അച്ചന്റെ': 'a t͡ʃ t͡ʃ a n ṯ e',
#  'അച്ചൻറെ': 'a t͡ʃ t͡ʃ a n r e',
#  'അച്ചാ': 'a t͡ʃ t͡ʃ aː',
#  'അച്ചാച്ചൻ': 'a t͡ʃ t͡ʃ aː t͡ʃ t͡ʃ a n',
#  'അച്ചാമ്മ': 'a t͡ʃ t͡ʃ aː m m a',
#  'അച്ചായനെ': 'a t͡ʃ t͡ʃ aː j a n e',
#  'അച്ചായന്': 'a t͡ʃ t͡ʃ aː j a n ə',
#  'അച്ചായൻ': 'a t͡ʃ t͡ʃ aː j a n',
#  'അച്ചായന്റെ': 'a t͡ʃ t͡ʃ aː j a n ṯ e',
#  'അച്ചായാ': 'a t͡ʃ t͡ʃ aː j aː',
#  'അച്ചാരം': 'a t͡ʃ t͡ʃ aː ɾ a m',
#  'അച്ചാർ': 'a t͡ʃ t͡ʃ aː r',
#  'അച്ചാറും': 'a t͡ʃ t͡ʃ aː r u m',
#  'അച്ചാറുകൾ': 'a t͡ʃ t͡ʃ aː r u k a ɭ',
#  'അച്ചാറോ': 'a t͡ʃ t͡ʃ aː r oː',
#  'അച്ചിൽ': 'a t͡ʃ t͡ʃ i l',
#  'അച്ചില്ലി': 'a t͡ʃ t͡ʃ i l l i',
#  'അച്ചീവ്മെന്റ്': 'a t͡ʃ t͡ʃ iː ʋ m e n ṯ ə',
#  'അച്ചു': 'a t͡ʃ t͡ʃ u',
#  'അച്ചുകളും': 'a t͡ʃ t͡ʃ u k a ɭ u m',
#  'അച്ചുകൾ': 'a t͡ʃ t͡ʃ u k a ɭ',
#  'അച്ചുതണ്ടിൽ': 'a t͡ʃ t͡ʃ u t̪ a ɳ ʈ i l',
#  'അച്ചുതണ്ടു': 'a t͡ʃ t͡ʃ u t̪ a ɳ ʈ u',
#  'അച്ചുതണ്ട്': 'a t͡ʃ t͡ʃ u t̪ a ɳ ʈ ə',
#  'അച്ചുതൻ': 'a t͡ʃ t͡ʃ u t̪ a n',
#  'അച്ചുതാനന്ദൻ': 'a t͡ʃ t͡ʃ u t̪ aː n a n̪ d̪ a n',
#  'അച്ചുതാനന്ദന്റെ': 'a t͡ʃ t͡ʃ u t̪ aː n a n̪ d̪ a n ṯ e',
#  'അച്ചുവിന്റെ': 'a t͡ʃ t͡ʃ u ʋ i n ṯ e',
#  'അച്ച്ഛന്റെ': 'a t͡ʃ t͡ʃ t͡ʃʰ a n ṯ e',
#  'അച്ഛനമ്മമാരും': 'a t͡ʃ t͡ʃʰ a n a m m a m aː ɾ u m',
#  'അച്ഛനമ്മമാരുടെ': 'a t͡ʃ t͡ʃʰ a n a m m a m aː ɾ u ʈ e',
#  'അച്ഛനമ്മമാരെ': 'a t͡ʃ t͡ʃʰ a n a m m a m aː ɾ e',
#  'അച്ഛനമ്മമാർ': 'a t͡ʃ t͡ʃʰ a n a m m a m aː r',
#  'അച്ഛനമ്മമാർക്കോ': 'a t͡ʃ t͡ʃʰ a n a m m a m aː r k k oː',
#  'അച്ഛനമ്മമാർക്ക്': 'a t͡ʃ t͡ʃʰ a n a m m a m aː r k k ə',
#  'അച്ഛനാണ്': 'a t͡ʃ t͡ʃʰ a n aː ɳ ə',
#  'അച്ഛനായ': 'a t͡ʃ t͡ʃʰ a n aː j a',
#  'അച്ഛനായി': 'a t͡ʃ t͡ʃʰ a n aː j i',
#  'അച്ഛനിൽ': 'a t͡ʃ t͡ʃʰ a n i l',
#  'അച്ഛനു': 'a t͡ʃ t͡ʃʰ a n u',
#  'അച്ഛനും': 'a t͡ʃ t͡ʃʰ a n u m',
#  'അച്ഛനുമമ്മയും': 'a t͡ʃ t͡ʃʰ a n u m a m m a j u m',
#  'അച്ഛനുമമ്മേം': 'a t͡ʃ t͡ʃʰ a n u m a m m eː m',
#  'അച്ഛനുമായി': 'a t͡ʃ t͡ʃʰ a n u m aː j i',
#  'അച്ഛനുറങ്ങാത്ത': 'a t͡ʃ t͡ʃʰ a n u r a ŋ ŋ aː t̪ t̪ a',
#  'അച്ഛനെ': 'a t͡ʃ t͡ʃʰ a n e',
#  'അച്ഛനെയും': 'a t͡ʃ t͡ʃʰ a n e j u m',
#  'അച്ഛനേയും': 'a t͡ʃ t͡ʃʰ a n eː j u m',
#  'അച്ഛനൊപ്പം': 'a t͡ʃ t͡ʃʰ a n o p p a m',
#  'അച്ഛനോ': 'a t͡ʃ t͡ʃʰ a n oː',
#  'അച്ഛനോടും': 'a t͡ʃ t͡ʃʰ a n oː ʈ u m',
#  'അച്ഛനോടൊപ്പം': 'a t͡ʃ t͡ʃʰ a n oː ʈ o p p a m',
#  'അച്ഛനോട്': 'a t͡ʃ t͡ʃʰ a n oː ʈ ə',
#  'അച്ഛന്': 'a t͡ʃ t͡ʃʰ a n ə',
#  'അച്ഛൻ': 'a t͡ʃ t͡ʃʰ a n',
#  'അച്ഛന്മാർ': 'a t͡ʃ t͡ʃʰ a n m aː r',
#  'അച്ഛൻവീട്ടിൽ': 'a t͡ʃ t͡ʃʰ a n ʋ iː ʈ ʈ i l',
#  'അച്ഛന്റെ': 'a t͡ʃ t͡ʃʰ a n ṯ e',
#  'അച്ഛൻറെ': 'a t͡ʃ t͡ʃʰ a n r e',
#  'അച്ഛന്റെയും': 'a t͡ʃ t͡ʃʰ a n ṯ e j u m',
#  'അച്ഛന്റേയും': 'a t͡ʃ t͡ʃʰ a n ṯ eː j u m',
#  'അച്ഛമ്മ': 'a t͡ʃ t͡ʃʰ a m m a',
#  'അച്ഛമ്മയുടെ': 'a t͡ʃ t͡ʃʰ a m m a j u ʈ e',
#  'അച്ഛാ': 'a t͡ʃ t͡ʃʰ aː',
#  'അച്ഛേ': 'a t͡ʃ t͡ʃʰ eː',
#  'അച്യുത': 'a t͡ʃ j u t̪ a',
#  'അച്യുതൻ': 'a t͡ʃ j u t̪ a n',
#  'അച്യുതമേനോൻ': 'a t͡ʃ j u t̪ a m eː n oː n',
#  'അച്യുതമേനോന്റെ': 'a t͡ʃ j u t̪ a m eː n oː n ṯ e',
#  'അച്യുതാനന്ദനും': 'a t͡ʃ j u t̪ aː n a n̪ d̪ a n u m',
#  'അച്യുതാനന്ദനെ': 'a t͡ʃ j u t̪ aː n a n̪ d̪ a n e',
#  'അച്യുതാനന്ദനെതിരെ': 'a t͡ʃ j u t̪ aː n a n̪ d̪ a n e t̪ i ɾ e',
#  'അച്യുതാനന്ദന്': 'a t͡ʃ j u t̪ aː n a n̪ d̪ a n ə',
#  'അച്യുതാനന്ദൻ': 'a t͡ʃ j u t̪ aː n a n̪ d̪ a n',
#  'അച്യുതാനന്ദന്റെ': 'a t͡ʃ j u t̪ aː n a n̪ d̪ a n ṯ e',
#  'അച്യുതാന്ദൻ': 'a t͡ʃ j u t̪ aː n̪ d̪ a n',
#  'അഛനും': 'a t͡ʃʰ a n u m',
#  'അഛനെ': 'a t͡ʃʰ a n e',
#  'അഛൻ': 'a t͡ʃʰ a n',
#  'അഛന്റെ': 'a t͡ʃʰ a n ṯ e',
#  'അഛി': 'a t͡ʃʰ i',
#  'അജണ്ട': 'a ɟ a ɳ ʈ a',
#  'അജണ്ടകൾ': 'a ɟ a ɳ ʈ a k a ɭ',
#  'അജണ്ടയാണ്': 'a ɟ a ɳ ʈ a j aː ɳ ə',
#  'അജണ്ടയായി': 'a ɟ a ɳ ʈ a j aː j i',
#  'അജണ്ടയിൽ': 'a ɟ a ɳ ʈ a j i l',
#  'അജണ്ടയും': 'a ɟ a ɳ ʈ a j u m',
#  'അജണ്ടയുടെ': 'a ɟ a ɳ ʈ a j u ʈ e',
#  'അംജദ്': 'a m ɟ a d̪ ə',
#  'അജൻഡ': 'a ɟ a n ɖ a',
#  'അജൻഡകൾ': 'a ɟ a n ɖ a k a ɭ',
#  'അജൻഡയിൽ': 'a ɟ a n ɖ a j i l',
#  'അജൻഡയുടെ': 'a ɟ a n ɖ a j u ʈ e',
#  'അജന്ത': 'a ɟ a n̪ t̪ a',
#  'അജപാലന': 'a ɟ a p aː l a n a',
#  'അജയകുമാർ': 'a ɟ a j a k u m aː r',
#  'അജയൻ': 'a ɟ a j a n',
#  'അജയന്റെ': 'a ɟ a j a n ṯ e',
#  'അജയ്': 'a ɟ a j ə',
#  'അജയ്യത': 'a ɟ a j j a t̪ a',
#  'അജയ്യനായി': 'a ɟ a j j a n aː j i',
#  'അജയ്യമായിത്തീർന്നു': 'a ɟ a j j a m aː j i t̪ t̪ iː r n̪ n̪ u',
#  'അജാക്സ്': 'a ɟ aː k s ə',
#  'അജാതശത്രു': 'a ɟ aː t̪ a a t̪ r u',
#  'അജാനൂർ': 'a ɟ aː n uː r',
#  'അജാസ്': 'a ɟ aː s ə',
#  'അജി': 'a ɟ i',
#  'അജികുമാർ': 'a ɟ i k u m aː r',
#  'അജിങ്ക്യ': 'a ɟ i ŋ k j a',
#  'അജിങ്ക്യാ': 'a ɟ i ŋ k j aː',
#  'അജിത': 'a ɟ i t̪ a',
#  'അജിതയും': 'a ɟ i t̪ a j u m',
#  'അജിതയുടെ': 'a ɟ i t̪ a j u ʈ e',
#  'അജിതാ': 'a ɟ i t̪ aː',
#  'അജിതിനെ': 'a ɟ i t̪ i n e',
#  'അജിത്': 'a ɟ i t̪ ə',
#  'അജിത്കുമാർ': 'a ɟ i t̪ k u m aː r',
#  'അജിത്തിനെ': 'a ɟ i t̪ t̪ i n e',
#  'അജിത്തിന്': 'a ɟ i t̪ t̪ i n ə',
#  'അജിത്തിന്റെ': 'a ɟ i t̪ t̪ i n ṯ e',
#  'അജിത്തും': 'a ɟ i t̪ t̪ u m',
#  'അജിത്തേട്ടാ': 'a ɟ i t̪ t̪ eː ʈ ʈ aː',
#  'അജിത്ത്': 'a ɟ i t̪ t̪ ə',
#  'അജിൻക്യ': 'a ɟ i n k j a',
#  'അജീഷ്': 'a ɟ iː ʂ ə',
#  'അജു': 'a ɟ u',
#  'അജേഷ്': 'a ɟ eː ʂ ə',
#  'അജൈവ': 'a ɟ ai̯ ʋ a',
#  'അജൈവിക': 'a ɟ ai̯ ʋ i k a',
#  'അജോയ്': 'a ɟ oː j ə',
#  'അജ്ഞത': 'a ɟ ɲ a t̪ a',
#  'അജ്ഞതയും': 'a ɟ ɲ a t̪ a j u m',
#  'അജ്ഞതയുടെ': 'a ɟ ɲ a t̪ a j u ʈ e',
#  'അജ്ഞാത': 'a ɟ ɲ aː t̪ a',
#  'അജ്ഞാതനായ': 'a ɟ ɲ aː t̪ a n aː j a',
#  'അജ്ഞാതൻ': 'a ɟ ɲ aː t̪ a n',
#  'അജ്ഞാതന്റെ': 'a ɟ ɲ aː t̪ a n ṯ e',
#  'അജ്ഞാതമാണെങ്കിലും': 'a ɟ ɲ aː t̪ a m aː ɳ e ŋ k i l u m',
#  'അജ്ഞാതമാണ്': 'a ɟ ɲ aː t̪ a m aː ɳ ə',
#  'അജ്ഞാതമായ': 'a ɟ ɲ aː t̪ a m aː j a',
#  'അജ്ഞാതമായി': 'a ɟ ɲ aː t̪ a m aː j i',
#  'അജ്ഞാതമായിരുന്നു': 'a ɟ ɲ aː t̪ a m aː j i ɾ u n̪ n̪ u',
#  'അജ്ഞാതരായ': 'a ɟ ɲ aː t̪ a ɾ aː j a',
#  'അജ്ഞാതരുടെ': 'a ɟ ɲ aː t̪ a ɾ u ʈ e',
#  'അജ്ഞാതർ': 'a ɟ ɲ aː t̪ a r',
#  'അജ്ഞാതവാസം': 'a ɟ ɲ aː t̪ a ʋ aː s a m',
#  'അജ്ഞാനം': 'a ɟ ɲ aː n a m',
#  'അജ്ഞാനപ്രതീകമായ': 'a ɟ ɲ aː n a p r a t̪ iː k a m aː j a',
#  'അജ്മൽ': 'a ɟ m a l',
#  'അജ്മാനിലെ': 'a ɟ m aː n i l e',
#  'അജ്മാനിൽ': 'a ɟ m aː n i l',
#  'അജ്മാൻ': 'a ɟ m aː n',
#  'അജ്മീർ': 'a ɟ m iː r',
#  'അജ്മീറിലെ': 'a ɟ m iː r i l e',
#  'അജ്മീറിലെത്തുന്ന': 'a ɟ m iː r i l e t̪ t̪ u n̪ n̪ a',
#  'അജ്മീറിൽ': 'a ɟ m iː r i l',
#  'അഞ്ചംഗ': 'a ɲ t͡ʃ a m ɡ a',
#  'അഞ്ചടി': 'a ɲ t͡ʃ a ʈ i',
#  'അഞ്ചര': 'a ɲ t͡ʃ a ɾ a',
#  'അഞ്ചരക്കണ്ടി': 'a ɲ t͡ʃ a ɾ a k k a ɳ ʈ i',
#  'അഞ്ചരയോടെ': 'a ɲ t͡ʃ a ɾ a j oː ʈ e',
#  'അഞ്ചലിലെ': 'a ɲ t͡ʃ a l i l e',
#  'അഞ്ചലിൽ': 'a ɲ t͡ʃ a l i l',
#  'അഞ്ചൽ': 'a ɲ t͡ʃ a l',
#  'അഞ്ചൽക്കാരൻ': 'a ɲ t͡ʃ a l k k aː ɾ a n',
#  'അഞ്ചാം': 'a ɲ t͡ʃ aː m',
#  'അഞ്ചാക്ഷരമായ': 'a ɲ t͡ʃ aː k ʂ a ɾ a m aː j a',
#  'അഞ്ചാംനാൾ': 'a ɲ t͡ʃ aː m n aː ɭ',
#  'അഞ്ചാംപനി': 'a ɲ t͡ʃ aː m p a n i',
#  'അഞ്ചാമത്': 'a ɲ t͡ʃ aː m a t̪ ə',
#  'അഞ്ചാമത്തെ': 'a ɲ t͡ʃ aː m a t̪ t̪ e',
#  'അഞ്ചാമനെ': 'a ɲ t͡ʃ aː m a n e',
#  'അഞ്ചാമൻ': 'a ɲ t͡ʃ aː m a n',
#  'അഞ്ചായി': 'a ɲ t͡ʃ aː j i',
#  'അഞ്ചാലുംമൂട്': 'a ɲ t͡ʃ aː l u m m uː ʈ ə',
#  'അഞ്ചാംവട്ടവും': 'a ɲ t͡ʃ aː m ʋ a ʈ ʈ a ʋ u m',
#  'അഞ്ചാറു': 'a ɲ t͡ʃ aː r u',
#  'അഞ്ചാറ്': 'a ɲ t͡ʃ aː r ə',
#  'അഞ്ചിടങ്ങളിൽ': 'a ɲ t͡ʃ i ʈ a ŋ ŋ a ɭ i l',
#  'അഞ്ചിനകം': 'a ɲ t͡ʃ i n a k a m',
#  'അഞ്ചിനാണ്': 'a ɲ t͡ʃ i n aː ɳ ə',
#  'അഞ്ചിനു': 'a ɲ t͡ʃ i n u',
#  'അഞ്ചിനും': 'a ɲ t͡ʃ i n u m',
#  'അഞ്ചിന്': 'a ɲ t͡ʃ i n ə',
#  'അഞ്ചിരട്ടി': 'a ɲ t͡ʃ i ɾ a ʈ ʈ i',
#  'അഞ്ചിലും': 'a ɲ t͡ʃ i l u m',
#  'അഞ്ചിലൊന്ന്': 'a ɲ t͡ʃ i l o n̪ n̪ ə',
#  'അഞ്ചിൽ': 'a ɲ t͡ʃ i l',
#  'അഞ്ചു': 'a ɲ t͡ʃ u',
#  'അഞ്ചും': 'a ɲ t͡ʃ u m',
#  'അഞ്ചുകൊല്ലം': 'a ɲ t͡ʃ u k o l l a m',
#  'അഞ്ചുകോടി': 'a ɲ t͡ʃ u k oː ʈ i',
#  'അഞ്ചുതരം': 'a ɲ t͡ʃ u t̪ a ɾ a m',
#  'അഞ്ചുതവണ': 'a ɲ t͡ʃ u t̪ a ʋ a ɳ a',
#  'അഞ്ചുതെങ്ങിൽ': 'a ɲ t͡ʃ u t̪ e ŋ ŋ i l',
#  'അഞ്ചുതെങ്ങ്': 'a ɲ t͡ʃ u t̪ e ŋ ŋ ə',
#  'അഞ്ചുദിവസം': 'a ɲ t͡ʃ u d̪ i ʋ a s a m',
#  'അഞ്ചുനാടുകൾ': 'a ɲ t͡ʃ u n aː ʈ u k a ɭ',
#  'അഞ്ചുനാഴികത്തോട്': 'a ɲ t͡ʃ u n aː ɻ i k a t̪ t̪ oː ʈ ə',
#  'അഞ്ചുപേരും': 'a ɲ t͡ʃ u p eː ɾ u m',
#  'അഞ്ചുപേരുടെ': 'a ɲ t͡ʃ u p eː ɾ u ʈ e',
#  'അഞ്ചുപേരെ': 'a ɲ t͡ʃ u p eː ɾ e',
#  'അഞ്ചുപേർ': 'a ɲ t͡ʃ u p eː r',
#  'അഞ്ചുപേർക്ക്': 'a ɲ t͡ʃ u p eː r k k ə',
#  'അഞ്ചുമണിക്ക്': 'a ɲ t͡ʃ u m a ɳ i k k ə',
#  'അഞ്ചുമണിയോടെ': 'a ɲ t͡ʃ u m a ɳ i j oː ʈ e',
#  'അഞ്ചുമാസം': 'a ɲ t͡ʃ u m aː s a m',
#  'അഞ്ചുമാസത്തിനകം': 'a ɲ t͡ʃ u m aː s a t̪ t̪ i n a k a m',
#  'അഞ്ചുമുതൽ': 'a ɲ t͡ʃ u m u t̪ a l',
#  'അഞ്ചുരൂപ': 'a ɲ t͡ʃ u ɾ uː p a',
#  'അഞ്ചുലക്ഷം': 'a ɲ t͡ʃ u l a k ʂ a m',
#  'അഞ്ചുവരെ': 'a ɲ t͡ʃ u ʋ a ɾ e',
#  'അഞ്ചുവർഷം': 'a ɲ t͡ʃ u ʋ a r ʂ a m',
#  'അഞ്ചുവർഷത്തിനുള്ളിൽ': 'a ɲ t͡ʃ u ʋ a r ʂ a t̪ t̪ i n u ɭ ɭ i l',
#  'അഞ്ചുവർഷത്തെ': 'a ɲ t͡ʃ u ʋ a r ʂ a t̪ t̪ e',
#  'അഞ്ചുവർഷത്തേക്ക്': 'a ɲ t͡ʃ u ʋ a r ʂ a t̪ t̪ eː k k ə',
#  'അഞ്ചുവർഷമായി': 'a ɲ t͡ʃ u ʋ a r ʂ a m aː j i',
#  'അഞ്ചുശതമാനം': 'a ɲ t͡ʃ u a t̪ a m aː n a m',
#  'അഞ്ചുസെന്റ്': 'a ɲ t͡ʃ u s e n ṯ ə',
#  'അഞ്ചെട്ടു': 'a ɲ t͡ʃ e ʈ ʈ u',
#  'അഞ്ചെണ്ണം': 'a ɲ t͡ʃ e ɳ ɳ a m',
#  ...}

# %%
# Generate lexicon file 
with open("ml_lexicon.txt", "w", encoding = "utf-8") as out_file:
    for word, ipa in ml_ipa.items():
        out_file.write(word + " " + ipa + "\n")
